# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
from matplotlib.lines import Line2D
import matplotlib
font = {'size':16}
matplotlib.rc('font', **font)
import seaborn as sns
from joblib import Parallel, delayed
import math
from scipy.stats import multivariate_normal

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def online_sample_from_task_sequence(t, N=20, d=2):
    if (t // N) % 2 == 0:
        mu = np.array([1, 1])
    else:
        mu = np.array([-3, -3])    
    Y = np.random.binomial(1, 0.5)
    X = np.random.multivariate_normal((-1)**(Y+1)*mu, np.eye(d))
    return X, 2*Y-1

# %%
class LinearLayer(nn.Module):
    def __init__(self, d_model, hidden_dim, p):
        super().__init__()
        self.linear1 = nn.Linear(d_model,    hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        return x

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, conv_hidden_dim, p=0.1):
        super().__init__()

        self.mha = nn.MultiheadAttention(d_model, num_heads, p)
        self.cnn = LinearLayer(d_model, conv_hidden_dim, p)

        self.layernorm1 = nn.LayerNorm(normalized_shape=d_model, eps=1e-6)
        self.layernorm2 = nn.LayerNorm(normalized_shape=d_model, eps=1e-6)
    
    def forward(self, x):
        attn_output, _ = self.mha(x, x, x)
        out1 = self.layernorm1(x + attn_output)
        cnn_output = self.cnn(out1)
        out2 = self.layernorm2(out1 + cnn_output)
        return out2
    
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout= 0.0, max_len= 5000):
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(1, max_len, d_model)
        theta = np.array([
            [p / np.power(10000, 2 * (j // 2) / d_model) for j in range(d_model)]
            for p in range(max_len)
        ])
        pe[:, :, 0::2] = torch.FloatTensor(np.sin(theta[:, 0::2]))
        pe[:, :, 1::2] = torch.FloatTensor(np.cos(theta[:, 1::2]))
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe
        return self.dropout(x)
    
class TransformerClassifier(nn.Module):
    def __init__(self, input_size, lookback_length, d_model, num_heads, conv_hidden_dim, num_classes):
        super().__init__()

        self.transformer_encoder = EncoderLayer(d_model, num_heads, conv_hidden_dim)
        self.dense = nn.Linear(d_model, num_classes)
        self.input_embedding = nn.Linear(input_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_len=lookback_length+1)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.input_embedding(x)
        x = self.positional_encoding(x)
        x = self.transformer_encoder(x)
        x, _ = torch.max(x, dim=1)
        x = self.dense(x)
        x = self.softmax(x)
        return x

# %%
def create_dataset(sequence, labels, look_back=1):
    X, Y = [], []
    for i in range(len(sequence)-look_back-1):
        temp = sequence[i:(i+look_back+1), :]
        X.append(temp)
        Y.append(labels[i + look_back])
    return np.array(X), np.array(Y)

class create_dataset_for_pytorch(Dataset):
    def __init__(self, N, T, lookback=25):
        X_train = np.empty((0, 2))
        Y_train = np.empty((0,))

        for t in range(1, T+1):
            x, y = online_sample_from_task_sequence(t, N)
            if y < 0: y = 0

            X_train = np.concatenate((X_train, x.reshape(1, 2)), axis=0)
            Y_train = np.append(Y_train, y)

        X, Y = create_dataset(X_train, Y_train, look_back=lookback)
        X = torch.Tensor(X)
        Y = torch.Tensor(Y)
        self.X = X
        self.Y = Y
        self.X_train = X_train
        self.Y_train = Y_train

    def get_data_stream(self):
        return self.X_train, self.Y_train

    def __len__(self):
        return len(self.Y)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# %%
N = 20
T = 1000
lookback = 60

# %%
train_dataset = create_dataset_for_pytorch(N, T, lookback)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
model = TransformerClassifier(
    input_size=2,
    lookback_length=lookback,
    d_model=16,
    num_heads=8,
    conv_hidden_dim=32,
    num_classes=2
)
model.to(device)
# Out:
# TransformerClassifier(
#   (transformer_encoder): EncoderLayer(
#     (mha): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#     )
#     (cnn): CNN(
#       (k1convL1): Linear(in_features=16, out_features=32, bias=True)
#       (k1convL2): Linear(in_features=32, out_features=16, bias=True)
#       (activation): ReLU()
#     )
#     (layernorm1): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#     (layernorm2): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#   )
#   (dense): Linear(in_features=16, out_features=2, bias=True)
#   (input_embedding): Linear(in_features=2, out_features=16, bias=True)
#   (positional_encoding): PositionalEncoding(
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (softmax): Softmax(dim=1)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
num_epochs = 500

# %%
for epoch in range(num_epochs):
    model.train()
    nb_batches = len(train_dataloader)
    losses = 0.0
    train_acc = 0.0
    for x, y in train_dataloader:
        x = x.to(device)
        y = y.long().to(device)
        out = model(x)
        loss = criterion(out, y)
        model.zero_grad()
        loss.backward()
        losses += loss.item()
        optimizer.step()
        train_acc += (out.argmax(1) == y).cpu().numpy().mean()
    print("Training loss at epoch {} : {:4f}, Training Acc : {:4f}".format(epoch+1, losses/nb_batches, train_acc/nb_batches))
# Out:
# Training loss at epoch 1 : 0.703522, Training Acc : 0.508523
# Training loss at epoch 2 : 0.694786, Training Acc : 0.504640
# Training loss at epoch 3 : 0.695006, Training Acc : 0.488163
# Training loss at epoch 4 : 0.694036, Training Acc : 0.507670
# Training loss at epoch 5 : 0.693544, Training Acc : 0.506913
# Training loss at epoch 6 : 0.692500, Training Acc : 0.522159
# Training loss at epoch 7 : 0.693995, Training Acc : 0.490057
# Training loss at epoch 8 : 0.693824, Training Acc : 0.499621
# Training loss at epoch 9 : 0.693489, Training Acc : 0.488920
# Training loss at epoch 10 : 0.692907, Training Acc : 0.508712
# Training loss at epoch 11 : 0.692444, Training Acc : 0.518371
# Training loss at epoch 12 : 0.694011, Training Acc : 0.489015
# Training loss at epoch 13 : 0.693166, Training Acc : 0.514015
# Training loss at epoch 14 : 0.692965, Training Acc : 0.518182
# Training loss at epoch 15 : 0.693486, Training Acc : 0.506534
# Training loss at epoch 16 : 0.693231, Training Acc : 0.498769
# Training loss at epoch 17 : 0.693318, Training Acc : 0.507765
# Training loss at epoch 18 : 0.693630, Training Acc : 0.503788
# Training loss at epoch 19 : 0.693487, Training Acc : 0.508807
# Training loss at epoch 20 : 0.692524, Training Acc : 0.493087
# Training loss at epoch 21 : 0.692796, Training Acc : 0.514205
# Training loss at epoch 22 : 0.693373, Training Acc : 0.516098
# Training loss at epoch 23 : 0.691892, Training Acc : 0.518277
# Training loss at epoch 24 : 0.691859, Training Acc : 0.515152
# Training loss at epoch 25 : 0.692724, Training Acc : 0.518087
# Training loss at epoch 26 : 0.693049, Training Acc : 0.515152
# Training loss at epoch 27 : 0.692175, Training Acc : 0.532765
# Training loss at epoch 28 : 0.691820, Training Acc : 0.501515
# Training loss at epoch 29 : 0.692196, Training Acc : 0.517898
# Training loss at epoch 30 : 0.692399, Training Acc : 0.525568
# Training loss at epoch 31 : 0.691823, Training Acc : 0.505777
# Training loss at epoch 32 : 0.692314, Training Acc : 0.532481
# Training loss at epoch 33 : 0.691483, Training Acc : 0.533523
# Training loss at epoch 34 : 0.692372, Training Acc : 0.520549
# Training loss at epoch 35 : 0.692237, Training Acc : 0.508902
# Training loss at epoch 36 : 0.692337, Training Acc : 0.505682
# Training loss at epoch 37 : 0.691419, Training Acc : 0.537027
# Training loss at epoch 38 : 0.691487, Training Acc : 0.538826
# Training loss at epoch 39 : 0.691617, Training Acc : 0.520360
# Training loss at epoch 40 : 0.691400, Training Acc : 0.536837
# Training loss at epoch 41 : 0.691806, Training Acc : 0.544034
# Training loss at epoch 42 : 0.690807, Training Acc : 0.525379
# Training loss at epoch 43 : 0.691127, Training Acc : 0.533712
# Training loss at epoch 44 : 0.691540, Training Acc : 0.525473
# Training loss at epoch 45 : 0.691288, Training Acc : 0.547538
# Training loss at epoch 46 : 0.691546, Training Acc : 0.519413
# Training loss at epoch 47 : 0.691617, Training Acc : 0.507860
# Training loss at epoch 48 : 0.691313, Training Acc : 0.532765
# Training loss at epoch 49 : 0.691163, Training Acc : 0.526136
# Training loss at epoch 50 : 0.690785, Training Acc : 0.546023
# Training loss at epoch 51 : 0.691130, Training Acc : 0.530682
# Training loss at epoch 52 : 0.690884, Training Acc : 0.542992
# Training loss at epoch 53 : 0.690783, Training Acc : 0.547443
# Training loss at epoch 54 : 0.690534, Training Acc : 0.531913
# Training loss at epoch 55 : 0.690044, Training Acc : 0.540814
# Training loss at epoch 56 : 0.691457, Training Acc : 0.545455
# Training loss at epoch 57 : 0.690925, Training Acc : 0.545076
# Training loss at epoch 58 : 0.690936, Training Acc : 0.534091
# Training loss at epoch 59 : 0.691658, Training Acc : 0.520549
# Training loss at epoch 60 : 0.691084, Training Acc : 0.535890
# Training loss at epoch 61 : 0.690653, Training Acc : 0.542140
# Training loss at epoch 62 : 0.690319, Training Acc : 0.539773
# Training loss at epoch 63 : 0.690242, Training Acc : 0.541951
# Training loss at epoch 64 : 0.690431, Training Acc : 0.539867
# Training loss at epoch 65 : 0.688881, Training Acc : 0.548295
# Training loss at epoch 66 : 0.689146, Training Acc : 0.539867
# Training loss at epoch 67 : 0.690542, Training Acc : 0.519602
# Training loss at epoch 68 : 0.688966, Training Acc : 0.540341
# Training loss at epoch 69 : 0.689538, Training Acc : 0.525379
# Training loss at epoch 70 : 0.690297, Training Acc : 0.554640
# Training loss at epoch 71 : 0.688531, Training Acc : 0.562027
# Training loss at epoch 72 : 0.689236, Training Acc : 0.546496
# Training loss at epoch 73 : 0.690894, Training Acc : 0.538163
# Training loss at epoch 74 : 0.689163, Training Acc : 0.560795
# Training loss at epoch 75 : 0.689188, Training Acc : 0.543182
# Training loss at epoch 76 : 0.688252, Training Acc : 0.564962
# Training loss at epoch 77 : 0.689434, Training Acc : 0.558617
# Training loss at epoch 78 : 0.688771, Training Acc : 0.567424
# Training loss at epoch 79 : 0.688998, Training Acc : 0.553693
# Training loss at epoch 80 : 0.689537, Training Acc : 0.546686
# Training loss at epoch 81 : 0.687938, Training Acc : 0.561742
# Training loss at epoch 82 : 0.688511, Training Acc : 0.569129
# Training loss at epoch 83 : 0.688056, Training Acc : 0.566098
# Training loss at epoch 84 : 0.688340, Training Acc : 0.544413
# Training loss at epoch 85 : 0.687672, Training Acc : 0.570360
# Training loss at epoch 86 : 0.688466, Training Acc : 0.561080
# Training loss at epoch 87 : 0.687053, Training Acc : 0.571496
# Training loss at epoch 88 : 0.687259, Training Acc : 0.572159
# Training loss at epoch 89 : 0.687459, Training Acc : 0.570360
# Training loss at epoch 90 : 0.687732, Training Acc : 0.558807
# Training loss at epoch 91 : 0.686208, Training Acc : 0.571402
# Training loss at epoch 92 : 0.687039, Training Acc : 0.570076
# Training loss at epoch 93 : 0.686226, Training Acc : 0.599527
# Training loss at epoch 94 : 0.686408, Training Acc : 0.577367
# Training loss at epoch 95 : 0.687777, Training Acc : 0.551799
# Training loss at epoch 96 : 0.685562, Training Acc : 0.587784
# Training loss at epoch 97 : 0.684875, Training Acc : 0.597159
# Training loss at epoch 98 : 0.686672, Training Acc : 0.574527
# Training loss at epoch 99 : 0.685916, Training Acc : 0.591951
# Training loss at epoch 100 : 0.684864, Training Acc : 0.587973
# Training loss at epoch 101 : 0.684181, Training Acc : 0.593087
# Training loss at epoch 102 : 0.685032, Training Acc : 0.587879
# Training loss at epoch 103 : 0.685142, Training Acc : 0.558902
# Training loss at epoch 104 : 0.684831, Training Acc : 0.581723
# Training loss at epoch 105 : 0.685564, Training Acc : 0.579924
# Training loss at epoch 106 : 0.682788, Training Acc : 0.611742
# Training loss at epoch 107 : 0.683611, Training Acc : 0.576420
# Training loss at epoch 108 : 0.683532, Training Acc : 0.589867
# Training loss at epoch 109 : 0.683988, Training Acc : 0.575473
# Training loss at epoch 110 : 0.683246, Training Acc : 0.601326
# Training loss at epoch 111 : 0.683334, Training Acc : 0.571212
# Training loss at epoch 112 : 0.681875, Training Acc : 0.608712
# Training loss at epoch 113 : 0.681645, Training Acc : 0.610890
# Training loss at epoch 114 : 0.682412, Training Acc : 0.591383
# Training loss at epoch 115 : 0.682076, Training Acc : 0.592045
# Training loss at epoch 116 : 0.680452, Training Acc : 0.617898
# Training loss at epoch 117 : 0.679779, Training Acc : 0.619034
# Training loss at epoch 118 : 0.680862, Training Acc : 0.622348
# Training loss at epoch 119 : 0.679732, Training Acc : 0.615909
# Training loss at epoch 120 : 0.680058, Training Acc : 0.610038
# Training loss at epoch 121 : 0.678551, Training Acc : 0.626610
# Training loss at epoch 122 : 0.679146, Training Acc : 0.619223
# Training loss at epoch 123 : 0.677482, Training Acc : 0.640909
# Training loss at epoch 124 : 0.679826, Training Acc : 0.626610
# Training loss at epoch 125 : 0.676608, Training Acc : 0.619034
# Training loss at epoch 126 : 0.678237, Training Acc : 0.608807
# Training loss at epoch 127 : 0.676642, Training Acc : 0.615057
# Training loss at epoch 128 : 0.675699, Training Acc : 0.602462
# Training loss at epoch 129 : 0.674703, Training Acc : 0.635890
# Training loss at epoch 130 : 0.676219, Training Acc : 0.604924
# Training loss at epoch 131 : 0.676056, Training Acc : 0.627462
# Training loss at epoch 132 : 0.672499, Training Acc : 0.630492
# Training loss at epoch 133 : 0.672676, Training Acc : 0.632765
# Training loss at epoch 134 : 0.672641, Training Acc : 0.646117
# Training loss at epoch 135 : 0.670791, Training Acc : 0.653504
# Training loss at epoch 136 : 0.673106, Training Acc : 0.618087
# Training loss at epoch 137 : 0.669928, Training Acc : 0.625284
# Training loss at epoch 138 : 0.667584, Training Acc : 0.633428
# Training loss at epoch 139 : 0.668853, Training Acc : 0.639962
# Training loss at epoch 140 : 0.667990, Training Acc : 0.634848
# Training loss at epoch 141 : 0.667798, Training Acc : 0.648390
# Training loss at epoch 142 : 0.666609, Training Acc : 0.629451
# Training loss at epoch 143 : 0.665661, Training Acc : 0.644318
# Training loss at epoch 144 : 0.663142, Training Acc : 0.643845
# Training loss at epoch 145 : 0.663527, Training Acc : 0.654640
# Training loss at epoch 146 : 0.663955, Training Acc : 0.636932
# Training loss at epoch 147 : 0.662637, Training Acc : 0.627746
# Training loss at epoch 148 : 0.662451, Training Acc : 0.654640
# Training loss at epoch 149 : 0.659011, Training Acc : 0.659470
# Training loss at epoch 150 : 0.658589, Training Acc : 0.667140
# Training loss at epoch 151 : 0.657104, Training Acc : 0.655398
# Training loss at epoch 152 : 0.653390, Training Acc : 0.681629
# Training loss at epoch 153 : 0.656451, Training Acc : 0.645455
# Training loss at epoch 154 : 0.654586, Training Acc : 0.653598
# Training loss at epoch 155 : 0.650684, Training Acc : 0.694034
# Training loss at epoch 156 : 0.650440, Training Acc : 0.673201
# Training loss at epoch 157 : 0.647470, Training Acc : 0.675284
# Training loss at epoch 158 : 0.646390, Training Acc : 0.677367
# Training loss at epoch 159 : 0.647038, Training Acc : 0.667330
# Training loss at epoch 160 : 0.646768, Training Acc : 0.671117
# Training loss at epoch 161 : 0.641848, Training Acc : 0.664962
# Training loss at epoch 162 : 0.642777, Training Acc : 0.674337
# Training loss at epoch 163 : 0.643578, Training Acc : 0.675568
# Training loss at epoch 164 : 0.639113, Training Acc : 0.686837
# Training loss at epoch 165 : 0.641220, Training Acc : 0.668277
# Training loss at epoch 166 : 0.636692, Training Acc : 0.693087
# Training loss at epoch 167 : 0.633506, Training Acc : 0.695076
# Training loss at epoch 168 : 0.633539, Training Acc : 0.673295
# Training loss at epoch 169 : 0.633474, Training Acc : 0.666193
# Training loss at epoch 170 : 0.630841, Training Acc : 0.675284
# Training loss at epoch 171 : 0.628477, Training Acc : 0.684848
# Training loss at epoch 172 : 0.625611, Training Acc : 0.683523
# Training loss at epoch 173 : 0.627086, Training Acc : 0.674432
# Training loss at epoch 174 : 0.625991, Training Acc : 0.677462
# Training loss at epoch 175 : 0.626820, Training Acc : 0.677652
# Training loss at epoch 176 : 0.621226, Training Acc : 0.692898
# Training loss at epoch 177 : 0.619582, Training Acc : 0.693939
# Training loss at epoch 178 : 0.617330, Training Acc : 0.683617
# Training loss at epoch 179 : 0.620238, Training Acc : 0.685890
# Training loss at epoch 180 : 0.618962, Training Acc : 0.686837
# Training loss at epoch 181 : 0.612984, Training Acc : 0.685890
# Training loss at epoch 182 : 0.616337, Training Acc : 0.686837
# Training loss at epoch 183 : 0.613482, Training Acc : 0.700189
# Training loss at epoch 184 : 0.614750, Training Acc : 0.692140
# Training loss at epoch 185 : 0.608927, Training Acc : 0.704545
# Training loss at epoch 186 : 0.607579, Training Acc : 0.698106
# Training loss at epoch 187 : 0.610296, Training Acc : 0.704545
# Training loss at epoch 188 : 0.608707, Training Acc : 0.689015
# Training loss at epoch 189 : 0.610182, Training Acc : 0.687121
# Training loss at epoch 190 : 0.608121, Training Acc : 0.691951
# Training loss at epoch 191 : 0.603408, Training Acc : 0.695076
# Training loss at epoch 192 : 0.601430, Training Acc : 0.701515
# Training loss at epoch 193 : 0.607256, Training Acc : 0.684754
# Training loss at epoch 194 : 0.602211, Training Acc : 0.687784
# Training loss at epoch 195 : 0.601589, Training Acc : 0.699053
# Training loss at epoch 196 : 0.598726, Training Acc : 0.708523
# Training loss at epoch 197 : 0.600752, Training Acc : 0.691951
# Training loss at epoch 198 : 0.597347, Training Acc : 0.710417
# Training loss at epoch 199 : 0.597372, Training Acc : 0.694129
# Training loss at epoch 200 : 0.596459, Training Acc : 0.694034
# Training loss at epoch 201 : 0.597422, Training Acc : 0.690909
# Training loss at epoch 202 : 0.600386, Training Acc : 0.686080
# Training loss at epoch 203 : 0.594558, Training Acc : 0.696212
# Training loss at epoch 204 : 0.592438, Training Acc : 0.701326
# Training loss at epoch 205 : 0.593795, Training Acc : 0.694034
# Training loss at epoch 206 : 0.591445, Training Acc : 0.713826
# Training loss at epoch 207 : 0.592804, Training Acc : 0.707860
# Training loss at epoch 208 : 0.592474, Training Acc : 0.702367
# Training loss at epoch 209 : 0.587428, Training Acc : 0.705398
# Training loss at epoch 210 : 0.589141, Training Acc : 0.711742
# Training loss at epoch 211 : 0.588768, Training Acc : 0.714678
# Training loss at epoch 212 : 0.581782, Training Acc : 0.726231
# Training loss at epoch 213 : 0.588099, Training Acc : 0.698295
# Training loss at epoch 214 : 0.587034, Training Acc : 0.705777
# Training loss at epoch 215 : 0.583832, Training Acc : 0.709943
# Training loss at epoch 216 : 0.592526, Training Acc : 0.700284
# Training loss at epoch 217 : 0.582076, Training Acc : 0.727178
# Training loss at epoch 218 : 0.576019, Training Acc : 0.725095
# Training loss at epoch 219 : 0.576381, Training Acc : 0.736648
# Training loss at epoch 220 : 0.581356, Training Acc : 0.709754
# Training loss at epoch 221 : 0.580690, Training Acc : 0.726420
# Training loss at epoch 222 : 0.578777, Training Acc : 0.725473
# Training loss at epoch 223 : 0.575300, Training Acc : 0.730492
# Training loss at epoch 224 : 0.571865, Training Acc : 0.735511
# Training loss at epoch 225 : 0.565790, Training Acc : 0.736458
# Training loss at epoch 226 : 0.569709, Training Acc : 0.740625
# Training loss at epoch 227 : 0.568351, Training Acc : 0.740909
# Training loss at epoch 228 : 0.569309, Training Acc : 0.735795
# Training loss at epoch 229 : 0.565822, Training Acc : 0.725189
# Training loss at epoch 230 : 0.564255, Training Acc : 0.750189
# Training loss at epoch 231 : 0.564901, Training Acc : 0.742140
# Training loss at epoch 232 : 0.556956, Training Acc : 0.750284
# Training loss at epoch 233 : 0.554000, Training Acc : 0.761458
# Training loss at epoch 234 : 0.559516, Training Acc : 0.743561
# Training loss at epoch 235 : 0.547852, Training Acc : 0.771970
# Training loss at epoch 236 : 0.550224, Training Acc : 0.768087
# Training loss at epoch 237 : 0.547606, Training Acc : 0.776326
# Training loss at epoch 238 : 0.539800, Training Acc : 0.794886
# Training loss at epoch 239 : 0.534692, Training Acc : 0.818845
# Training loss at epoch 240 : 0.529812, Training Acc : 0.810701
# Training loss at epoch 241 : 0.532333, Training Acc : 0.795170
# Training loss at epoch 242 : 0.532998, Training Acc : 0.801326
# Training loss at epoch 243 : 0.520982, Training Acc : 0.828314
# Training loss at epoch 244 : 0.515350, Training Acc : 0.842898
# Training loss at epoch 245 : 0.505696, Training Acc : 0.855398
# Training loss at epoch 246 : 0.500169, Training Acc : 0.867708
# Training loss at epoch 247 : 0.499445, Training Acc : 0.861553
# Training loss at epoch 248 : 0.491716, Training Acc : 0.861553
# Training loss at epoch 249 : 0.488950, Training Acc : 0.850189
# Training loss at epoch 250 : 0.480777, Training Acc : 0.878125
# Training loss at epoch 251 : 0.470678, Training Acc : 0.880303
# Training loss at epoch 252 : 0.476460, Training Acc : 0.867992
# Training loss at epoch 253 : 0.461754, Training Acc : 0.883523
# Training loss at epoch 254 : 0.479862, Training Acc : 0.855303
# Training loss at epoch 255 : 0.470608, Training Acc : 0.873390
# Training loss at epoch 256 : 0.464784, Training Acc : 0.877367
# Training loss at epoch 257 : 0.461802, Training Acc : 0.881439
# Training loss at epoch 258 : 0.459810, Training Acc : 0.875095
# Training loss at epoch 259 : 0.451330, Training Acc : 0.883333
# Training loss at epoch 260 : 0.451452, Training Acc : 0.881250
# Training loss at epoch 261 : 0.449300, Training Acc : 0.882576
# Training loss at epoch 262 : 0.452564, Training Acc : 0.881345
# Training loss at epoch 263 : 0.456730, Training Acc : 0.880492
# Training loss at epoch 264 : 0.456148, Training Acc : 0.865909
# Training loss at epoch 265 : 0.445117, Training Acc : 0.890720
# Training loss at epoch 266 : 0.440215, Training Acc : 0.892708
# Training loss at epoch 267 : 0.430856, Training Acc : 0.906250
# Training loss at epoch 268 : 0.437128, Training Acc : 0.892803
# Training loss at epoch 269 : 0.441551, Training Acc : 0.875000
# Training loss at epoch 270 : 0.433864, Training Acc : 0.894981
# Training loss at epoch 271 : 0.441115, Training Acc : 0.884659
# Training loss at epoch 272 : 0.444042, Training Acc : 0.887595
# Training loss at epoch 273 : 0.440140, Training Acc : 0.885511
# Training loss at epoch 274 : 0.431504, Training Acc : 0.900189
# Training loss at epoch 275 : 0.433182, Training Acc : 0.899148
# Training loss at epoch 276 : 0.431634, Training Acc : 0.898958
# Training loss at epoch 277 : 0.428012, Training Acc : 0.891761
# Training loss at epoch 278 : 0.432424, Training Acc : 0.887595
# Training loss at epoch 279 : 0.431666, Training Acc : 0.889678
# Training loss at epoch 280 : 0.433320, Training Acc : 0.887689
# Training loss at epoch 281 : 0.424885, Training Acc : 0.905208
# Training loss at epoch 282 : 0.424843, Training Acc : 0.900095
# Training loss at epoch 283 : 0.439202, Training Acc : 0.877178
# Training loss at epoch 284 : 0.431850, Training Acc : 0.886648
# Training loss at epoch 285 : 0.430520, Training Acc : 0.891856
# Training loss at epoch 286 : 0.425261, Training Acc : 0.896875
# Training loss at epoch 287 : 0.427818, Training Acc : 0.894886
# Training loss at epoch 288 : 0.428851, Training Acc : 0.889773
# Training loss at epoch 289 : 0.419613, Training Acc : 0.905208
# Training loss at epoch 290 : 0.420808, Training Acc : 0.897064
# Training loss at epoch 291 : 0.426411, Training Acc : 0.889962
# Training loss at epoch 292 : 0.429844, Training Acc : 0.885511
# Training loss at epoch 293 : 0.421838, Training Acc : 0.900189
# Training loss at epoch 294 : 0.428559, Training Acc : 0.888826
# Training loss at epoch 295 : 0.421604, Training Acc : 0.888731
# Training loss at epoch 296 : 0.420316, Training Acc : 0.906345
# Training loss at epoch 297 : 0.420243, Training Acc : 0.900095
# Training loss at epoch 298 : 0.420062, Training Acc : 0.894034
# Training loss at epoch 299 : 0.418603, Training Acc : 0.903220
# Training loss at epoch 300 : 0.420072, Training Acc : 0.900189
# Training loss at epoch 301 : 0.421205, Training Acc : 0.900095
# Training loss at epoch 302 : 0.417706, Training Acc : 0.906250
# Training loss at epoch 303 : 0.417589, Training Acc : 0.905303
# Training loss at epoch 304 : 0.421077, Training Acc : 0.901136
# Training loss at epoch 305 : 0.416029, Training Acc : 0.908333
# Training loss at epoch 306 : 0.418782, Training Acc : 0.897917
# Training loss at epoch 307 : 0.421753, Training Acc : 0.904451
# Training loss at epoch 308 : 0.411896, Training Acc : 0.912500
# Training loss at epoch 309 : 0.421335, Training Acc : 0.900095
# Training loss at epoch 310 : 0.416221, Training Acc : 0.902083
# Training loss at epoch 311 : 0.421622, Training Acc : 0.898011
# Training loss at epoch 312 : 0.416611, Training Acc : 0.907481
# Training loss at epoch 313 : 0.413013, Training Acc : 0.911458
# Training loss at epoch 314 : 0.411161, Training Acc : 0.905208
# Training loss at epoch 315 : 0.415025, Training Acc : 0.907386
# Training loss at epoch 316 : 0.412754, Training Acc : 0.910417
# Training loss at epoch 317 : 0.412307, Training Acc : 0.907481
# Training loss at epoch 318 : 0.409486, Training Acc : 0.911458
# Training loss at epoch 319 : 0.414520, Training Acc : 0.904261
# Training loss at epoch 320 : 0.413820, Training Acc : 0.905303
# Training loss at epoch 321 : 0.413267, Training Acc : 0.904167
# Training loss at epoch 322 : 0.405673, Training Acc : 0.914583
# Training loss at epoch 323 : 0.410816, Training Acc : 0.908428
# Training loss at epoch 324 : 0.417884, Training Acc : 0.897917
# Training loss at epoch 325 : 0.411351, Training Acc : 0.909470
# Training loss at epoch 326 : 0.411661, Training Acc : 0.908333
# Training loss at epoch 327 : 0.416347, Training Acc : 0.902178
# Training loss at epoch 328 : 0.417222, Training Acc : 0.899148
# Training loss at epoch 329 : 0.411224, Training Acc : 0.912500
# Training loss at epoch 330 : 0.412362, Training Acc : 0.910511
# Training loss at epoch 331 : 0.408386, Training Acc : 0.904167
# Training loss at epoch 332 : 0.413269, Training Acc : 0.901042
# Training loss at epoch 333 : 0.412869, Training Acc : 0.901042
# Training loss at epoch 334 : 0.419805, Training Acc : 0.891951
# Training loss at epoch 335 : 0.410996, Training Acc : 0.906345
# Training loss at epoch 336 : 0.412791, Training Acc : 0.903220
# Training loss at epoch 337 : 0.413570, Training Acc : 0.904545
# Training loss at epoch 338 : 0.409762, Training Acc : 0.906439
# Training loss at epoch 339 : 0.412165, Training Acc : 0.907386
# Training loss at epoch 340 : 0.409205, Training Acc : 0.910606
# Training loss at epoch 341 : 0.407196, Training Acc : 0.915720
# Training loss at epoch 342 : 0.404212, Training Acc : 0.915625
# Training loss at epoch 343 : 0.415794, Training Acc : 0.903314
# Training loss at epoch 344 : 0.406505, Training Acc : 0.909564
# Training loss at epoch 345 : 0.410884, Training Acc : 0.903125
# Training loss at epoch 346 : 0.405971, Training Acc : 0.913731
# Training loss at epoch 347 : 0.406023, Training Acc : 0.913636
# Training loss at epoch 348 : 0.410937, Training Acc : 0.904356
# Training loss at epoch 349 : 0.407797, Training Acc : 0.911648
# Training loss at epoch 350 : 0.411477, Training Acc : 0.908617
# Training loss at epoch 351 : 0.405768, Training Acc : 0.911648
# Training loss at epoch 352 : 0.405615, Training Acc : 0.917803
# Training loss at epoch 353 : 0.403001, Training Acc : 0.919792
# Training loss at epoch 354 : 0.407197, Training Acc : 0.914678
# Training loss at epoch 355 : 0.412186, Training Acc : 0.906534
# Training loss at epoch 356 : 0.401943, Training Acc : 0.918750
# Training loss at epoch 357 : 0.408273, Training Acc : 0.907386
# Training loss at epoch 358 : 0.404711, Training Acc : 0.912689
# Training loss at epoch 359 : 0.407473, Training Acc : 0.902083
# Training loss at epoch 360 : 0.410424, Training Acc : 0.904356
# Training loss at epoch 361 : 0.408622, Training Acc : 0.911553
# Training loss at epoch 362 : 0.406680, Training Acc : 0.914773
# Training loss at epoch 363 : 0.411156, Training Acc : 0.902273
# Training loss at epoch 364 : 0.409423, Training Acc : 0.906439
# Training loss at epoch 365 : 0.401948, Training Acc : 0.918750
# Training loss at epoch 366 : 0.402215, Training Acc : 0.910417
# Training loss at epoch 367 : 0.403672, Training Acc : 0.918845
# Training loss at epoch 368 : 0.405895, Training Acc : 0.907386
# Training loss at epoch 369 : 0.403650, Training Acc : 0.913731
# Training loss at epoch 370 : 0.399958, Training Acc : 0.920928
# Training loss at epoch 371 : 0.403085, Training Acc : 0.914773
# Training loss at epoch 372 : 0.399909, Training Acc : 0.919886
# Training loss at epoch 373 : 0.407339, Training Acc : 0.905303
# Training loss at epoch 374 : 0.398577, Training Acc : 0.919886
# Training loss at epoch 375 : 0.407006, Training Acc : 0.906345
# Training loss at epoch 376 : 0.400212, Training Acc : 0.912500
# Training loss at epoch 377 : 0.409971, Training Acc : 0.908523
# Training loss at epoch 378 : 0.403422, Training Acc : 0.920833
# Training loss at epoch 379 : 0.405550, Training Acc : 0.911742
# Training loss at epoch 380 : 0.400635, Training Acc : 0.913542
# Training loss at epoch 381 : 0.400755, Training Acc : 0.910511
# Training loss at epoch 382 : 0.407552, Training Acc : 0.906345
# Training loss at epoch 383 : 0.399697, Training Acc : 0.918750
# Training loss at epoch 384 : 0.399503, Training Acc : 0.917708
# Training loss at epoch 385 : 0.398941, Training Acc : 0.921875
# Training loss at epoch 386 : 0.403432, Training Acc : 0.913731
# Training loss at epoch 387 : 0.404282, Training Acc : 0.914678
# Training loss at epoch 388 : 0.400723, Training Acc : 0.920833
# Training loss at epoch 389 : 0.402261, Training Acc : 0.915720
# Training loss at epoch 390 : 0.399523, Training Acc : 0.921970
# Training loss at epoch 391 : 0.412407, Training Acc : 0.901326
# Training loss at epoch 392 : 0.395284, Training Acc : 0.921875
# Training loss at epoch 393 : 0.399048, Training Acc : 0.921875
# Training loss at epoch 394 : 0.401122, Training Acc : 0.919981
# Training loss at epoch 395 : 0.400595, Training Acc : 0.914583
# Training loss at epoch 396 : 0.402650, Training Acc : 0.915720
# Training loss at epoch 397 : 0.400324, Training Acc : 0.916761
# Training loss at epoch 398 : 0.402406, Training Acc : 0.910511
# Training loss at epoch 399 : 0.400675, Training Acc : 0.918939
# Training loss at epoch 400 : 0.401436, Training Acc : 0.917803
# Training loss at epoch 401 : 0.400972, Training Acc : 0.917803
# Training loss at epoch 402 : 0.401854, Training Acc : 0.915720
# Training loss at epoch 403 : 0.396477, Training Acc : 0.927083
# Training loss at epoch 404 : 0.400747, Training Acc : 0.911553
# Training loss at epoch 405 : 0.403388, Training Acc : 0.913731
# Training loss at epoch 406 : 0.398225, Training Acc : 0.922917
# Training loss at epoch 407 : 0.398024, Training Acc : 0.918939
# Training loss at epoch 408 : 0.399083, Training Acc : 0.920833
# Training loss at epoch 409 : 0.398411, Training Acc : 0.919792
# Training loss at epoch 410 : 0.398607, Training Acc : 0.918750
# Training loss at epoch 411 : 0.396004, Training Acc : 0.922917
# Training loss at epoch 412 : 0.398047, Training Acc : 0.920928
# Training loss at epoch 413 : 0.396282, Training Acc : 0.927083
# Training loss at epoch 414 : 0.398222, Training Acc : 0.918845
# Training loss at epoch 415 : 0.401548, Training Acc : 0.916761
# Training loss at epoch 416 : 0.401667, Training Acc : 0.914773
# Training loss at epoch 417 : 0.400061, Training Acc : 0.920928
# Training loss at epoch 418 : 0.404398, Training Acc : 0.913636
# Training loss at epoch 419 : 0.400379, Training Acc : 0.913731
# Training loss at epoch 420 : 0.400315, Training Acc : 0.917898
# Training loss at epoch 421 : 0.392482, Training Acc : 0.927083
# Training loss at epoch 422 : 0.399561, Training Acc : 0.920928
# Training loss at epoch 423 : 0.400976, Training Acc : 0.920928
# Training loss at epoch 424 : 0.402103, Training Acc : 0.912595
# Training loss at epoch 425 : 0.396262, Training Acc : 0.917708
# Training loss at epoch 426 : 0.395768, Training Acc : 0.920833
# Training loss at epoch 427 : 0.395956, Training Acc : 0.923958
# Training loss at epoch 428 : 0.397344, Training Acc : 0.918750
# Training loss at epoch 429 : 0.400097, Training Acc : 0.917708
# Training loss at epoch 430 : 0.401081, Training Acc : 0.916761
# Training loss at epoch 431 : 0.398380, Training Acc : 0.916761
# Training loss at epoch 432 : 0.397802, Training Acc : 0.920833
# Training loss at epoch 433 : 0.397483, Training Acc : 0.924148
# Training loss at epoch 434 : 0.397307, Training Acc : 0.917992
# Training loss at epoch 435 : 0.396210, Training Acc : 0.916761
# Training loss at epoch 436 : 0.401757, Training Acc : 0.909470
# Training loss at epoch 437 : 0.396217, Training Acc : 0.920928
# Training loss at epoch 438 : 0.398553, Training Acc : 0.920833
# Training loss at epoch 439 : 0.399126, Training Acc : 0.917803
# Training loss at epoch 440 : 0.392895, Training Acc : 0.926042
# Training loss at epoch 441 : 0.395091, Training Acc : 0.918845
# Training loss at epoch 442 : 0.395177, Training Acc : 0.922917
# Training loss at epoch 443 : 0.396387, Training Acc : 0.921875
# Training loss at epoch 444 : 0.397390, Training Acc : 0.921970
# Training loss at epoch 445 : 0.402162, Training Acc : 0.916856
# Training loss at epoch 446 : 0.394563, Training Acc : 0.924148
# Training loss at epoch 447 : 0.397852, Training Acc : 0.919886
# Training loss at epoch 448 : 0.399060, Training Acc : 0.913731
# Training loss at epoch 449 : 0.393814, Training Acc : 0.923106
# Training loss at epoch 450 : 0.399693, Training Acc : 0.914678
# Training loss at epoch 451 : 0.394680, Training Acc : 0.926042
# Training loss at epoch 452 : 0.392346, Training Acc : 0.923958
# Training loss at epoch 453 : 0.399684, Training Acc : 0.912784
# Training loss at epoch 454 : 0.398513, Training Acc : 0.921023
# Training loss at epoch 455 : 0.401266, Training Acc : 0.910701
# Training loss at epoch 456 : 0.398776, Training Acc : 0.915720
# Training loss at epoch 457 : 0.401228, Training Acc : 0.916951
# Training loss at epoch 458 : 0.398536, Training Acc : 0.915720
# Training loss at epoch 459 : 0.395580, Training Acc : 0.921023
# Training loss at epoch 460 : 0.394373, Training Acc : 0.927083
# Training loss at epoch 461 : 0.393437, Training Acc : 0.922917
# Training loss at epoch 462 : 0.394324, Training Acc : 0.923011
# Training loss at epoch 463 : 0.394426, Training Acc : 0.920928
# Training loss at epoch 464 : 0.396268, Training Acc : 0.917708
# Training loss at epoch 465 : 0.394843, Training Acc : 0.924053
# Training loss at epoch 466 : 0.395319, Training Acc : 0.925095
# Training loss at epoch 467 : 0.395616, Training Acc : 0.925095
# Training loss at epoch 468 : 0.393939, Training Acc : 0.923958
# Training loss at epoch 469 : 0.393407, Training Acc : 0.916856
# Training loss at epoch 470 : 0.394600, Training Acc : 0.919792
# Training loss at epoch 471 : 0.397054, Training Acc : 0.923106
# Training loss at epoch 472 : 0.396441, Training Acc : 0.921875
# Training loss at epoch 473 : 0.394633, Training Acc : 0.923106
# Training loss at epoch 474 : 0.394367, Training Acc : 0.929167
# Training loss at epoch 475 : 0.391893, Training Acc : 0.932292
# Training loss at epoch 476 : 0.394517, Training Acc : 0.921970
# Training loss at epoch 477 : 0.394485, Training Acc : 0.922064
# Training loss at epoch 478 : 0.395751, Training Acc : 0.917708
# Training loss at epoch 479 : 0.397555, Training Acc : 0.913920
# Training loss at epoch 480 : 0.396813, Training Acc : 0.920833
# Training loss at epoch 481 : 0.393556, Training Acc : 0.918750
# Training loss at epoch 482 : 0.396355, Training Acc : 0.917898
# Training loss at epoch 483 : 0.396703, Training Acc : 0.920928
# Training loss at epoch 484 : 0.396684, Training Acc : 0.919886
# Training loss at epoch 485 : 0.395491, Training Acc : 0.920928
# Training loss at epoch 486 : 0.396872, Training Acc : 0.917803
# Training loss at epoch 487 : 0.395660, Training Acc : 0.921970
# Training loss at epoch 488 : 0.393711, Training Acc : 0.927083
# Training loss at epoch 489 : 0.393540, Training Acc : 0.920928
# Training loss at epoch 490 : 0.394140, Training Acc : 0.917708
# Training loss at epoch 491 : 0.394236, Training Acc : 0.929261
# Training loss at epoch 492 : 0.392920, Training Acc : 0.923958
# Training loss at epoch 493 : 0.395904, Training Acc : 0.917803
# Training loss at epoch 494 : 0.395321, Training Acc : 0.922064
# Training loss at epoch 495 : 0.395217, Training Acc : 0.919886
# Training loss at epoch 496 : 0.393562, Training Acc : 0.918750
# Training loss at epoch 497 : 0.393622, Training Acc : 0.930208
# Training loss at epoch 498 : 0.390214, Training Acc : 0.922917
# Training loss at epoch 499 : 0.391381, Training Acc : 0.923958
# Training loss at epoch 500 : 0.394126, Training Acc : 0.923106

# %% [markdown]
# ### Evaluate

# %%
data_iterator = iter(train_dataloader)
nb_batches = len(train_dataloader)
model.eval()
acc = 0 
for x, y in train_dataloader:
    x = x.to(device)
    y = y.long().to(device)
    out = model(x)
    acc += (out.argmax(1) == y).cpu().numpy().mean()

print(f"Train accuracy: {acc / nb_batches}")
# Out:
# Train accuracy: 0.9190340909090909

# %%
num_reps = 100

# %%
model.eval()
predictions = np.zeros((num_reps, T-1))
groundtruth = np.zeros((num_reps, T-1))
accuracy_list = []
X_train, Y_train = train_dataset.get_data_stream()
for rep in range(num_reps):
    X_test = np.empty((0, 2))
    Y_test = np.empty((0,))

    for t in range(T+1, 2*T+1):
        x, y = online_sample_from_task_sequence(t, N)
        if y < 0: y = 0

        X_test = np.concatenate((X_test, x.reshape(1, 2)), axis=0)
        Y_test = np.append(Y_test, y)
    
    X_test = np.concatenate((X_train, X_test))
    Y_test = np.concatenate((Y_train, Y_test)) 

    X_t, Y_t = create_dataset(X_test[T-lookback:], Y_test[T-lookback:], look_back=lookback)
    X_t = torch.Tensor(X_t).to(device)

    Y_pred = model(X_t).argmax(1).detach().numpy()
    predictions[rep, :] = Y_pred
    groundtruth[rep, :] = Y_t

    accuracy_list.append(np.mean(Y_pred == Y_t))

# %%
mean_error = np.mean(predictions != groundtruth, axis=0)
print("Average test accuracy : {:4f} +/- {:4f}".format(np.mean(accuracy_list), np.std(accuracy_list)))
# Out:
# Average test accuracy : 0.903393 +/- 0.008845

# %%
std_error = np.std(predictions != groundtruth, axis=0)
ci = std_error * 1.96/np.sqrt(num_reps)

# %%
fig, axes = plt.subplots(2, 1, figsize=(20, 8))
ax = axes[0]
end = 200+1
xlocs = np.arange(0, end, N)
for i, x in enumerate(xlocs):
    if i % 2 == 0:
        ax.add_artist(Rectangle((x, 0), N, 2, fc='orange', alpha=0.6))
    else:
        ax.add_artist(Rectangle((x, 0), N, 2, fc='b', alpha=0.6))
ax.set_ylim([-1, 5])
ax.set_xlim([xlocs[0], xlocs[-1]])
ax.legend(["task A", "task B"], loc=1, frameon=False, fontsize=16)
ax.axis('off')

sns.set_style("white")
sns.set_style("ticks")

ax = axes[1]
ax.plot(np.arange(1, end), mean_error[:end-1], c='k')
x = np.arange(1, end)
y = mean_error[:end-1]
c = ci[:end-1]
plt.fill_between(x, y-c, y+c, alpha=0.2, color='k')
ax.set_ylabel("Transformer" + "\n" + "Error", fontsize=16)
ax.spines[['right', 'top']].set_visible(False)
ax.tick_params(labelsize=13)
ax.set_xlim([xlocs[0], xlocs[-1]])
ax.set_ylim([0, 1])
plt.show()

# %% [markdown]
# ### Comparison with online learners

# %%
ogd_error = np.load('results/ogd_error.npy')
ftl_error = np.load('results/ftl_error.npy')
c_ogd = np.load('results/ogd_conf.npy')
c_ftl = np.load('results/ftl_conf.npy')

# %%
left = [['left1'], 
        ['left2'],]
right = [['right1'],
         ['right2']]
fig, axes = plt.subplot_mosaic([[left, right]], figsize=(20, 8))

ax = axes['left1']

sns.set_palette('pastel')

x, y = np.mgrid[-3:3:.1, -3:3:.1]
rv = multivariate_normal([0.8, 0.8], 0.20*np.eye(2))
data = np.dstack((x, y))
z1 = rv.pdf(data)
rv = multivariate_normal([-0.8, -0.8], 0.20*np.eye(2))
data = np.dstack((x, y))
z2 = rv.pdf(data)
z = z1 - z2
ax.contourf(x, y, z, cmap='bwr', levels=100, alpha=1, extend='both')

ax.plot([-1, 1], [-1, 1], c='k', lw=3, ls="dashed")
ax.scatter([0], [0], c='k', s=40)
ax.scatter([1], [1], c='k', s=40)
ax.scatter([-1], [-1], c='k', s=40)
ax.text(-0.4, 0, "O", size='small')
ax.text(-1.2, -1.2, r"$-\mu$", size='large', ha='right', color='white')
ax.text(1.2, 1.2, r"$\mu$", size='large', ha='left', color='white')
ax.set_xlim([-2.5, 2.5])
ax.set_ylim([-2.5, 2.5])
ax.set_aspect("equal")
ax.set_title("Task A", fontsize=16)
ax.spines[['right', 'top', 'bottom', 'left']].set_visible(False)
# ax.legend(["Y = 1", "Y = -1"], fontsize=13, frameon=False, loc=2)
ax.set_xticks([])
ax.set_yticks([])

ax = axes['left2']

x, y = np.mgrid[-3:3:.1, -3:3:.1]
rv = multivariate_normal([-1.2, -1.2], 0.20*np.eye(2))
data = np.dstack((x, y))
z1 = rv.pdf(data)
rv = multivariate_normal([1.2, 1.2], 0.20*np.eye(2))
data = np.dstack((x, y))
z2 = rv.pdf(data)
z = z1 - z2
ax.contourf(x, y, z, cmap='bwr', levels=100, alpha=1, extend='both')

ax.plot([-1, 1], [-1, 1], c='k', lw=3, ls="dashed")
ax.scatter([0], [0], c='k', s=40)
ax.scatter([1], [1], c='k', s=40)
ax.scatter([-1], [-1], c='k', s=40)
ax.text(-0.4, 0, "O", size='small')
ax.text(-1.2, -1.2, r"$-3\mu$", size='large', ha='right', color='white')
ax.text(1.2, 1.2, r"$3\mu$", size='large', ha='left', color='white')
ax.set_xlim([-2.5, 2.5])
ax.set_ylim([-2.5, 2.5])
ax.set_aspect("equal")
ax.set_title("Task B", fontsize=16)
ax.spines[['right', 'top', 'bottom', 'left']].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

ax = axes['right1']
xlocs = np.arange(0, end-1, N)
for i, x in enumerate(xlocs):
    if i % 2 == 0:
        ax.add_artist(Rectangle((x, 0), N, 1, fc='purple', alpha=0.6))
    else:
        ax.add_artist(Rectangle((x, 0), N, 1, fc='g', alpha=0.6))
ax.set_ylim([-1, 5])
ax.legend(["task A", "task B"], loc=1, frameon=False, fontsize=16)
ax.axis('off')

sns.set_style("white")
sns.set_style("ticks")
sns.set_palette('pastel')

ax = axes['right2']
ax.plot(np.arange(1, end-1), ogd_error[:end-1], c='#2c7bb6')
x = np.arange(1, end-1)
y = ogd_error[:end-1]
c = c_ogd[:end-1]
ax.fill_between(x, y-c, y+c, alpha=0.2, color='#2c7bb6')

ax.plot(np.arange(1, end-1), ftl_error[:end-1], c='#fdae61')
x = np.arange(1, end-1)
y = ftl_error[:end-1]
c = c_ftl[:end-1]
ax.fill_between(x, y-c, y+c, alpha=0.2, color='#fdae61')

ax.plot(np.arange(1, end), mean_error[:end-1], c='#d7191c')
x = np.arange(1, end)
y = mean_error[:end-1]
c = ci[:end-1]
ax.fill_between(x, y-c, y+c, alpha=0.2, color='#d7191c')

ax.set_ylabel("Error", fontsize=16)
ax.spines[['right', 'top']].set_visible(False)
ax.tick_params(labelsize=13)

legend_elements = [Line2D([0], [0], color='#2c7bb6', lw=4, label='Online Grad. Descent'),
                    Line2D([0], [0], color='#fdae61', lw=4, label='Follow-the-Leader'),
                    Line2D([0], [0], color='#d7191c', lw=4, label='Autoreg-Transformer'),
                ]

ax.legend(handles=legend_elements, loc=8, bbox_to_anchor=(0.2, -0.3, 0.5, 0.5), ncol=3, frameon=False)

axes['right1'].set_xlim(ax.get_xlim())
plt.subplots_adjust(wspace=-0.2)
plt.show()

# %%
fig.savefig("figures/transformer-results.pdf", bbox_inches='tight')
