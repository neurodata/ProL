# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
from matplotlib.lines import Line2D
import matplotlib
font = {'size':16}
matplotlib.rc('font', **font)
import seaborn as sns
from joblib import Parallel, delayed
import math
from scipy.stats import multivariate_normal

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

# %%
# generate data 
def online_sample_from_task_sequence(t, N=20, d=2):
    if (t // N) % 2 == 0:
        mu = np.array([1, 1])
    else:
        mu = np.array([-3, -3])    
    Y = np.random.binomial(1, 0.5)
    X = np.random.multivariate_normal((-1)**(Y+1)*mu, np.eye(d))
    return X, 2*Y-1

def batch_sample_from_task_sequence(n, t, N=20, d=2, seed=1996):
    if (t // N) % 2 == 0:
        mu = np.array([1, 1])
    else:
        mu = np.array([-3, -3])    
    X = np.concatenate((np.random.multivariate_normal((-1)*mu, np.eye(d), size=n // 2),
                        np.random.multivariate_normal(mu, np.eye(d), size=n // 2)))
    Y = np.concatenate((-np.ones(n // 2), np.ones(n // 2)))
    return X, Y

# %%
# transformer archiecture
class LinearLayer(nn.Module):
    def __init__(self, d_model, hidden_dim, p):
        super().__init__()
        self.linear1 = nn.Linear(d_model,    hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        return x

class AttentionLayer(nn.Module):
    def __init__(self, d_model, num_heads, conv_hidden_dim, p=0.1, causal=False):
        super().__init__()
        self.causal = causal

        self.mha = nn.MultiheadAttention(d_model, num_heads, p)
        self.cnn = LinearLayer(d_model, conv_hidden_dim, p)

        self.layernorm1 = nn.LayerNorm(normalized_shape=d_model, eps=1e-6)
        self.layernorm2 = nn.LayerNorm(normalized_shape=d_model, eps=1e-6)
    
    def forward(self, x):
        if self.causal:
            mask = torch.triu(torch.full((len(x), len(x)), float('-inf'), device=device), diagonal=1)
        else:
            mask = None
        attn_output, _ = self.mha(x, x, x, attn_mask=mask)
        out1 = self.layernorm1(x + attn_output)
        cnn_output = self.cnn(out1)
        out2 = self.layernorm2(out1 + cnn_output)
        return out2
    
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout= 0.0, max_len= 5000):
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(1, max_len, d_model)
        theta = np.array([
            [p / np.power(10000, 2 * (j // 2) / d_model) for j in range(d_model)]
            for p in range(max_len)
        ])
        pe[:, :, 0::2] = torch.FloatTensor(np.sin(theta[:, 0::2]))
        pe[:, :, 1::2] = torch.FloatTensor(np.cos(theta[:, 1::2]))
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe
        return self.dropout(x)
    
class TransformerClassifier(nn.Module):
    def __init__(self, input_size, lookback_length, d_model, num_heads, conv_hidden_dim, num_classes):
        super().__init__()

        self.causal_attention1 = AttentionLayer(d_model, num_heads, conv_hidden_dim, causal=True)
        self.causal_attention2 = AttentionLayer(d_model, num_heads, conv_hidden_dim, causal=True)
        self.causal_attention3 = AttentionLayer(d_model, num_heads, conv_hidden_dim, causal=True)
        self.causal_attention4 = AttentionLayer(d_model, num_heads, conv_hidden_dim, causal=True)
        self.self_attention1 = AttentionLayer(d_model, num_heads, conv_hidden_dim, causal=True)
        self.self_attention2 = AttentionLayer(d_model, num_heads, conv_hidden_dim, causal=True)

        self.dense1 = nn.Linear(d_model, input_size)
        self.dense2 = nn.Linear(d_model, num_classes)

        self.input_embedding = nn.Linear(input_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_len=lookback_length+1)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.input_embedding(x)
        x = self.positional_encoding(x)
        x = self.causal_attention1(x)
        x = self.causal_attention2(x)
        x = self.causal_attention3(x)
        x = self.causal_attention4(x)

        # reconstruction head
        recon = self.dense1(x)

        # prediction head
        x = self.self_attention1(x)
        x = self.self_attention2(x)
        label = self.dense2(x)

        return recon, label

# %%
# create training dataset
def create_dataset(sequence, labels, look_back=1):
    X, Y, Xshifted = [], [], []
    for i in range(len(sequence)-look_back-2):
        X.append(sequence[i:(i+look_back+1), :])
        Y.append(labels[i:(i+look_back+1)])
        Xshifted.append(sequence[i+1:(i+look_back+2), :])
    return np.array(X), np.array(Y), np.array(Xshifted)

class create_dataset_for_pytorch(Dataset):
    def __init__(self, N, T, lookback=25):
        X_train = np.empty((0, 2))
        Y_train = np.empty((0,))

        for t in range(1, T+1):
            x, y = online_sample_from_task_sequence(t, N)
            if y < 0: y = 0

            X_train = np.concatenate((X_train, x.reshape(1, 2)), axis=0)
            Y_train = np.append(Y_train, y)

        X, Y, Xshifted = create_dataset(X_train, Y_train, look_back=lookback)
        X = torch.Tensor(X)
        Y = torch.Tensor(Y)
        Xshifted = torch.Tensor(Xshifted)
        self.X = X
        self.Y = Y
        self.Xshifted = Xshifted
        self.X_train = X_train
        self.Y_train = Y_train

    def get_data_stream(self):
        return self.X_train, self.Y_train

    def __len__(self):
        return len(self.Y)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx], self.Xshifted[idx]

# %%
N = 10
T = 1000
lookback = 30

# %%
train_dataset = create_dataset_for_pytorch(N, T, lookback)
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# %%
model = TransformerClassifier(
    input_size=2,
    lookback_length=lookback,
    d_model=16,
    num_heads=8,
    conv_hidden_dim=32,
    num_classes=2
)
model.to(device)
# Out:
# TransformerClassifier(
#   (causal_attention1): AttentionLayer(
#     (mha): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=16, out_features=16, bias=True)
#     )
#     (cnn): LinearLayer(
#       (linear1): Linear(in_features=16, out_features=32, bias=True)
#       (linear2): Linear(in_features=32, out_features=16, bias=True)
#       (relu): ReLU()
#     )
#     (layernorm1): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#     (layernorm2): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#   )
#   (causal_attention2): AttentionLayer(
#     (mha): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=16, out_features=16, bias=True)
#     )
#     (cnn): LinearLayer(
#       (linear1): Linear(in_features=16, out_features=32, bias=True)
#       (linear2): Linear(in_features=32, out_features=16, bias=True)
#       (relu): ReLU()
#     )
#     (layernorm1): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#     (layernorm2): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#   )
#   (causal_attention3): AttentionLayer(
#     (mha): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=16, out_features=16, bias=True)
#     )
#     (cnn): LinearLayer(
#       (linear1): Linear(in_features=16, out_features=32, bias=True)
#       (linear2): Linear(in_features=32, out_features=16, bias=True)
#       (relu): ReLU()
#     )
#     (layernorm1): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#     (layernorm2): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#   )
#   (causal_attention4): AttentionLayer(
#     (mha): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=16, out_features=16, bias=True)
#     )
#     (cnn): LinearLayer(
#       (linear1): Linear(in_features=16, out_features=32, bias=True)
#       (linear2): Linear(in_features=32, out_features=16, bias=True)
#       (relu): ReLU()
#     )
#     (layernorm1): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#     (layernorm2): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#   )
#   (self_attention1): AttentionLayer(
#     (mha): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=16, out_features=16, bias=True)
#     )
#     (cnn): LinearLayer(
#       (linear1): Linear(in_features=16, out_features=32, bias=True)
#       (linear2): Linear(in_features=32, out_features=16, bias=True)
#       (relu): ReLU()
#     )
#     (layernorm1): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#     (layernorm2): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#   )
#   (self_attention2): AttentionLayer(
#     (mha): MultiheadAttention(
#       (out_proj): _LinearWithBias(in_features=16, out_features=16, bias=True)
#     )
#     (cnn): LinearLayer(
#       (linear1): Linear(in_features=16, out_features=32, bias=True)
#       (linear2): Linear(in_features=32, out_features=16, bias=True)
#       (relu): ReLU()
#     )
#     (layernorm1): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#     (layernorm2): LayerNorm((16,), eps=1e-06, elementwise_affine=True)
#   )
#   (dense1): Linear(in_features=16, out_features=2, bias=True)
#   (dense2): Linear(in_features=16, out_features=2, bias=True)
#   (input_embedding): Linear(in_features=2, out_features=16, bias=True)
#   (positional_encoding): PositionalEncoding(
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (softmax): Softmax(dim=1)
# )

# %%
def criterion(zp, yp, z, y):
    cross_entropy_loss = nn.CrossEntropyLoss()
    mse_loss = nn.MSELoss()
    return cross_entropy_loss(yp, y) + 0*mse_loss(zp, z)

optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
num_epochs = 1000

# %%
for epoch in range(num_epochs):
    model.train()
    nb_batches = len(train_dataloader)
    losses = 0.0
    train_acc = 0.0
    for x, y, xshifted in train_dataloader:
        x = x.to(device)
        y = y.long().to(device)
        xshifted = xshifted.to(device)

        hat_xshifted, hat_y = model(x)
        loss = criterion(hat_xshifted, hat_y.transpose(1, 2), xshifted, y)

        model.zero_grad()
        loss.backward()
        losses += loss.item()
        optimizer.step()
        train_acc += (hat_y[:, -1].argmax(1) == y[:, -1]).cpu().numpy().mean()
    print("Training loss at epoch {} : {:4f}, Training Acc : {:4f}".format(epoch+1, losses/nb_batches, train_acc/nb_batches))
# Out:
# Training loss at epoch 1 : 0.865127, Training Acc : 0.423828
# Training loss at epoch 2 : 0.699733, Training Acc : 0.600586
# Training loss at epoch 3 : 0.670850, Training Acc : 0.600586
# Training loss at epoch 4 : 0.660133, Training Acc : 0.602539
# Training loss at epoch 5 : 0.652981, Training Acc : 0.595703
# Training loss at epoch 6 : 0.649291, Training Acc : 0.597656
# Training loss at epoch 7 : 0.645799, Training Acc : 0.608398
# Training loss at epoch 8 : 0.642468, Training Acc : 0.582031
# Training loss at epoch 9 : 0.641721, Training Acc : 0.588867
# Training loss at epoch 10 : 0.637270, Training Acc : 0.566406
# Training loss at epoch 11 : 0.635352, Training Acc : 0.579102
# Training loss at epoch 12 : 0.633468, Training Acc : 0.593750
# Training loss at epoch 13 : 0.631674, Training Acc : 0.582031
# Training loss at epoch 14 : 0.631404, Training Acc : 0.599609
# Training loss at epoch 15 : 0.630174, Training Acc : 0.585938
# Training loss at epoch 16 : 0.627496, Training Acc : 0.574219
# Training loss at epoch 17 : 0.624001, Training Acc : 0.576172
# Training loss at epoch 18 : 0.621921, Training Acc : 0.570312
# Training loss at epoch 19 : 0.620278, Training Acc : 0.549805
# Training loss at epoch 20 : 0.621033, Training Acc : 0.583984
# Training loss at epoch 21 : 0.618000, Training Acc : 0.572266
# Training loss at epoch 22 : 0.614277, Training Acc : 0.563477
# Training loss at epoch 23 : 0.612149, Training Acc : 0.586914
# Training loss at epoch 24 : 0.611396, Training Acc : 0.569336
# Training loss at epoch 25 : 0.609419, Training Acc : 0.582031
# Training loss at epoch 26 : 0.606136, Training Acc : 0.575195
# Training loss at epoch 27 : 0.605062, Training Acc : 0.586914
# Training loss at epoch 28 : 0.603800, Training Acc : 0.586914
# Training loss at epoch 29 : 0.601285, Training Acc : 0.584961
# Training loss at epoch 30 : 0.597016, Training Acc : 0.584961
# Training loss at epoch 31 : 0.592207, Training Acc : 0.574219
# Training loss at epoch 32 : 0.591795, Training Acc : 0.582031
# Training loss at epoch 33 : 0.587804, Training Acc : 0.583008
# Training loss at epoch 34 : 0.585686, Training Acc : 0.586914
# Training loss at epoch 35 : 0.581874, Training Acc : 0.612305
# Training loss at epoch 36 : 0.579224, Training Acc : 0.626953
# Training loss at epoch 37 : 0.573166, Training Acc : 0.608398
# Training loss at epoch 38 : 0.567615, Training Acc : 0.650391
# Training loss at epoch 39 : 0.560334, Training Acc : 0.661133
# Training loss at epoch 40 : 0.552500, Training Acc : 0.673828
# Training loss at epoch 41 : 0.541831, Training Acc : 0.701172
# Training loss at epoch 42 : 0.529431, Training Acc : 0.720703
# Training loss at epoch 43 : 0.515953, Training Acc : 0.750977
# Training loss at epoch 44 : 0.493485, Training Acc : 0.769531
# Training loss at epoch 45 : 0.469792, Training Acc : 0.791992
# Training loss at epoch 46 : 0.451296, Training Acc : 0.823242
# Training loss at epoch 47 : 0.438962, Training Acc : 0.792969
# Training loss at epoch 48 : 0.430127, Training Acc : 0.844727
# Training loss at epoch 49 : 0.413617, Training Acc : 0.792969
# Training loss at epoch 50 : 0.408899, Training Acc : 0.822266
# Training loss at epoch 51 : 0.410387, Training Acc : 0.834961
# Training loss at epoch 52 : 0.404799, Training Acc : 0.802734
# Training loss at epoch 53 : 0.401190, Training Acc : 0.820312
# Training loss at epoch 54 : 0.396471, Training Acc : 0.834961
# Training loss at epoch 55 : 0.394454, Training Acc : 0.830078
# Training loss at epoch 56 : 0.393949, Training Acc : 0.842773
# Training loss at epoch 57 : 0.389976, Training Acc : 0.818359
# Training loss at epoch 58 : 0.382151, Training Acc : 0.847656
# Training loss at epoch 59 : 0.380186, Training Acc : 0.831055
# Training loss at epoch 60 : 0.373223, Training Acc : 0.812500
# Training loss at epoch 61 : 0.376646, Training Acc : 0.840820
# Training loss at epoch 62 : 0.371903, Training Acc : 0.828125
# Training loss at epoch 63 : 0.369627, Training Acc : 0.830078
# Training loss at epoch 64 : 0.373597, Training Acc : 0.822266
# Training loss at epoch 65 : 0.363454, Training Acc : 0.841797
# Training loss at epoch 66 : 0.364326, Training Acc : 0.834961
# Training loss at epoch 67 : 0.367919, Training Acc : 0.843750
# Training loss at epoch 68 : 0.361443, Training Acc : 0.833008
# Training loss at epoch 69 : 0.359292, Training Acc : 0.856445
# Training loss at epoch 70 : 0.354173, Training Acc : 0.834961
# Training loss at epoch 71 : 0.355198, Training Acc : 0.828125
# Training loss at epoch 72 : 0.351407, Training Acc : 0.835938
# Training loss at epoch 73 : 0.358254, Training Acc : 0.833984
# Training loss at epoch 74 : 0.350447, Training Acc : 0.857422
# Training loss at epoch 75 : 0.352201, Training Acc : 0.839844
# Training loss at epoch 76 : 0.346331, Training Acc : 0.864258
# Training loss at epoch 77 : 0.343482, Training Acc : 0.856445
# Training loss at epoch 78 : 0.345296, Training Acc : 0.857422
# Training loss at epoch 79 : 0.339502, Training Acc : 0.846680
# Training loss at epoch 80 : 0.337198, Training Acc : 0.830078
# Training loss at epoch 81 : 0.334326, Training Acc : 0.851562
# Training loss at epoch 82 : 0.340358, Training Acc : 0.851562
# Training loss at epoch 83 : 0.336290, Training Acc : 0.864258
# Training loss at epoch 84 : 0.337004, Training Acc : 0.859375
# Training loss at epoch 85 : 0.336191, Training Acc : 0.860352
# Training loss at epoch 86 : 0.333728, Training Acc : 0.861328
# Training loss at epoch 87 : 0.331565, Training Acc : 0.843750
# Training loss at epoch 88 : 0.333599, Training Acc : 0.832031
# Training loss at epoch 89 : 0.325296, Training Acc : 0.858398
# Training loss at epoch 90 : 0.326720, Training Acc : 0.850586
# Training loss at epoch 91 : 0.322214, Training Acc : 0.856445
# Training loss at epoch 92 : 0.325492, Training Acc : 0.868164
# Training loss at epoch 93 : 0.321995, Training Acc : 0.868164
# Training loss at epoch 94 : 0.324397, Training Acc : 0.860352
# Training loss at epoch 95 : 0.325248, Training Acc : 0.856445
# Training loss at epoch 96 : 0.320937, Training Acc : 0.857422
# Training loss at epoch 97 : 0.323026, Training Acc : 0.848633
# Training loss at epoch 98 : 0.316813, Training Acc : 0.877930
# Training loss at epoch 99 : 0.316543, Training Acc : 0.876953
# Training loss at epoch 100 : 0.318163, Training Acc : 0.883789
# Training loss at epoch 101 : 0.319276, Training Acc : 0.866211
# Training loss at epoch 102 : 0.313224, Training Acc : 0.863281
# Training loss at epoch 103 : 0.313560, Training Acc : 0.867188
# Training loss at epoch 104 : 0.314102, Training Acc : 0.866211
# Training loss at epoch 105 : 0.314887, Training Acc : 0.863281
# Training loss at epoch 106 : 0.313882, Training Acc : 0.873047
# Training loss at epoch 107 : 0.311710, Training Acc : 0.877930
# Training loss at epoch 108 : 0.317044, Training Acc : 0.871094
# Training loss at epoch 109 : 0.313053, Training Acc : 0.864258
# Training loss at epoch 110 : 0.310186, Training Acc : 0.858398
# Training loss at epoch 111 : 0.310043, Training Acc : 0.863281
# Training loss at epoch 112 : 0.312098, Training Acc : 0.860352
# Training loss at epoch 113 : 0.307880, Training Acc : 0.866211
# Training loss at epoch 114 : 0.306227, Training Acc : 0.872070
# Training loss at epoch 115 : 0.307822, Training Acc : 0.870117
# Training loss at epoch 116 : 0.306009, Training Acc : 0.879883
# Training loss at epoch 117 : 0.311069, Training Acc : 0.867188
# Training loss at epoch 118 : 0.307477, Training Acc : 0.862305
# Training loss at epoch 119 : 0.308029, Training Acc : 0.881836
# Training loss at epoch 120 : 0.307151, Training Acc : 0.862305
# Training loss at epoch 121 : 0.303959, Training Acc : 0.861328
# Training loss at epoch 122 : 0.309380, Training Acc : 0.874023
# Training loss at epoch 123 : 0.303247, Training Acc : 0.875000
# Training loss at epoch 124 : 0.304997, Training Acc : 0.849609
# Training loss at epoch 125 : 0.298860, Training Acc : 0.865234
# Training loss at epoch 126 : 0.304347, Training Acc : 0.874023
# Training loss at epoch 127 : 0.300680, Training Acc : 0.876953
# Training loss at epoch 128 : 0.305457, Training Acc : 0.866211
# Training loss at epoch 129 : 0.301359, Training Acc : 0.874023
# Training loss at epoch 130 : 0.297621, Training Acc : 0.860352
# Training loss at epoch 131 : 0.300434, Training Acc : 0.866211
# Training loss at epoch 132 : 0.298283, Training Acc : 0.875000
# Training loss at epoch 133 : 0.302469, Training Acc : 0.866211
# Training loss at epoch 134 : 0.301005, Training Acc : 0.867188
# Training loss at epoch 135 : 0.299379, Training Acc : 0.879883
# Training loss at epoch 136 : 0.300886, Training Acc : 0.862305
# Training loss at epoch 137 : 0.302034, Training Acc : 0.869141
# Training loss at epoch 138 : 0.297761, Training Acc : 0.865234
# Training loss at epoch 139 : 0.299960, Training Acc : 0.852539
# Training loss at epoch 140 : 0.298121, Training Acc : 0.870117
# Training loss at epoch 141 : 0.301433, Training Acc : 0.883789
# Training loss at epoch 142 : 0.297337, Training Acc : 0.861328
# Training loss at epoch 143 : 0.298258, Training Acc : 0.875000
# Training loss at epoch 144 : 0.295670, Training Acc : 0.882812
# Training loss at epoch 145 : 0.296740, Training Acc : 0.879883
# Training loss at epoch 146 : 0.295310, Training Acc : 0.860352
# Training loss at epoch 147 : 0.300466, Training Acc : 0.866211
# Training loss at epoch 148 : 0.295862, Training Acc : 0.881836
# Training loss at epoch 149 : 0.296051, Training Acc : 0.875977
# Training loss at epoch 150 : 0.296738, Training Acc : 0.860352
# Training loss at epoch 151 : 0.297399, Training Acc : 0.862305
# Training loss at epoch 152 : 0.293081, Training Acc : 0.871094
# Training loss at epoch 153 : 0.293931, Training Acc : 0.875000
# Training loss at epoch 154 : 0.292967, Training Acc : 0.855469
# Training loss at epoch 155 : 0.293946, Training Acc : 0.879883
# Training loss at epoch 156 : 0.293228, Training Acc : 0.866211
# Training loss at epoch 157 : 0.293608, Training Acc : 0.875000
# Training loss at epoch 158 : 0.289590, Training Acc : 0.872070
# Training loss at epoch 159 : 0.292789, Training Acc : 0.859375
# Training loss at epoch 160 : 0.294331, Training Acc : 0.865234
# Training loss at epoch 161 : 0.293450, Training Acc : 0.885742
# Training loss at epoch 162 : 0.293351, Training Acc : 0.877930
# Training loss at epoch 163 : 0.295059, Training Acc : 0.849609
# Training loss at epoch 164 : 0.298143, Training Acc : 0.871094
# Training loss at epoch 165 : 0.294308, Training Acc : 0.873047
# Training loss at epoch 166 : 0.290719, Training Acc : 0.875977
# Training loss at epoch 167 : 0.294903, Training Acc : 0.875977
# Training loss at epoch 168 : 0.293188, Training Acc : 0.872070
# Training loss at epoch 169 : 0.293206, Training Acc : 0.864258
# Training loss at epoch 170 : 0.294252, Training Acc : 0.880859
# Training loss at epoch 171 : 0.290480, Training Acc : 0.880859
# Training loss at epoch 172 : 0.291704, Training Acc : 0.880859
# Training loss at epoch 173 : 0.294635, Training Acc : 0.884766
# Training loss at epoch 174 : 0.294221, Training Acc : 0.864258
# Training loss at epoch 175 : 0.288801, Training Acc : 0.866211
# Training loss at epoch 176 : 0.293216, Training Acc : 0.885742
# Training loss at epoch 177 : 0.290184, Training Acc : 0.871094
# Training loss at epoch 178 : 0.289093, Training Acc : 0.873047
# Training loss at epoch 179 : 0.288695, Training Acc : 0.862305
# Training loss at epoch 180 : 0.287745, Training Acc : 0.881836
# Training loss at epoch 181 : 0.286445, Training Acc : 0.870117
# Training loss at epoch 182 : 0.295439, Training Acc : 0.872070
# Training loss at epoch 183 : 0.288041, Training Acc : 0.870117
# Training loss at epoch 184 : 0.291768, Training Acc : 0.875977
# Training loss at epoch 185 : 0.293091, Training Acc : 0.877930
# Training loss at epoch 186 : 0.289671, Training Acc : 0.876953
# Training loss at epoch 187 : 0.288906, Training Acc : 0.883789
# Training loss at epoch 188 : 0.289323, Training Acc : 0.868164
# Training loss at epoch 189 : 0.292772, Training Acc : 0.872070
# Training loss at epoch 190 : 0.288831, Training Acc : 0.884766
# Training loss at epoch 191 : 0.287366, Training Acc : 0.877930
# Training loss at epoch 192 : 0.293512, Training Acc : 0.881836
# Training loss at epoch 193 : 0.289588, Training Acc : 0.871094
# Training loss at epoch 194 : 0.286805, Training Acc : 0.876953
# Training loss at epoch 195 : 0.287940, Training Acc : 0.865234
# Training loss at epoch 196 : 0.290062, Training Acc : 0.882812
# Training loss at epoch 197 : 0.286679, Training Acc : 0.871094
# Training loss at epoch 198 : 0.289260, Training Acc : 0.874023
# Training loss at epoch 199 : 0.290783, Training Acc : 0.870117
# Training loss at epoch 200 : 0.290644, Training Acc : 0.868164
# Training loss at epoch 201 : 0.286153, Training Acc : 0.883789
# Training loss at epoch 202 : 0.286859, Training Acc : 0.861328
# Training loss at epoch 203 : 0.287635, Training Acc : 0.877930
# Training loss at epoch 204 : 0.286983, Training Acc : 0.879883
# Training loss at epoch 205 : 0.287063, Training Acc : 0.889648
# Training loss at epoch 206 : 0.287173, Training Acc : 0.873047
# Training loss at epoch 207 : 0.288039, Training Acc : 0.871094
# Training loss at epoch 208 : 0.289555, Training Acc : 0.872070
# Training loss at epoch 209 : 0.286517, Training Acc : 0.880859
# Training loss at epoch 210 : 0.285782, Training Acc : 0.861328
# Training loss at epoch 211 : 0.287147, Training Acc : 0.867188
# Training loss at epoch 212 : 0.287308, Training Acc : 0.880859
# Training loss at epoch 213 : 0.288186, Training Acc : 0.880859
# Training loss at epoch 214 : 0.284652, Training Acc : 0.865234
# Training loss at epoch 215 : 0.287031, Training Acc : 0.877930
# Training loss at epoch 216 : 0.285195, Training Acc : 0.879883
# Training loss at epoch 217 : 0.286747, Training Acc : 0.883789
# Training loss at epoch 218 : 0.286090, Training Acc : 0.865234
# Training loss at epoch 219 : 0.284548, Training Acc : 0.863281
# Training loss at epoch 220 : 0.288122, Training Acc : 0.877930
# Training loss at epoch 221 : 0.284236, Training Acc : 0.869141
# Training loss at epoch 222 : 0.285785, Training Acc : 0.873047
# Training loss at epoch 223 : 0.286542, Training Acc : 0.884766
# Training loss at epoch 224 : 0.285613, Training Acc : 0.880859
# Training loss at epoch 225 : 0.282788, Training Acc : 0.880859
# Training loss at epoch 226 : 0.285472, Training Acc : 0.869141
# Training loss at epoch 227 : 0.282494, Training Acc : 0.879883
# Training loss at epoch 228 : 0.284872, Training Acc : 0.865234
# Training loss at epoch 229 : 0.283418, Training Acc : 0.882812
# Training loss at epoch 230 : 0.285859, Training Acc : 0.886719
# Training loss at epoch 231 : 0.283425, Training Acc : 0.886719
# Training loss at epoch 232 : 0.284197, Training Acc : 0.868164
# Training loss at epoch 233 : 0.284757, Training Acc : 0.871094
# Training loss at epoch 234 : 0.284202, Training Acc : 0.875977
# Training loss at epoch 235 : 0.284008, Training Acc : 0.874023
# Training loss at epoch 236 : 0.284671, Training Acc : 0.869141
# Training loss at epoch 237 : 0.285082, Training Acc : 0.872070
# Training loss at epoch 238 : 0.286288, Training Acc : 0.874023
# Training loss at epoch 239 : 0.283835, Training Acc : 0.881836
# Training loss at epoch 240 : 0.282595, Training Acc : 0.875000
# Training loss at epoch 241 : 0.284010, Training Acc : 0.880859
# Training loss at epoch 242 : 0.284999, Training Acc : 0.881836
# Training loss at epoch 243 : 0.283050, Training Acc : 0.859375
# Training loss at epoch 244 : 0.281557, Training Acc : 0.868164
# Training loss at epoch 245 : 0.285230, Training Acc : 0.867188
# Training loss at epoch 246 : 0.285061, Training Acc : 0.878906
# Training loss at epoch 247 : 0.284826, Training Acc : 0.883789
# Training loss at epoch 248 : 0.283243, Training Acc : 0.869141
# Training loss at epoch 249 : 0.284171, Training Acc : 0.876953
# Training loss at epoch 250 : 0.283489, Training Acc : 0.883789
# Training loss at epoch 251 : 0.285060, Training Acc : 0.885742
# Training loss at epoch 252 : 0.283897, Training Acc : 0.872070
# Training loss at epoch 253 : 0.285456, Training Acc : 0.876953
# Training loss at epoch 254 : 0.285266, Training Acc : 0.858398
# Training loss at epoch 255 : 0.285325, Training Acc : 0.880859
# Training loss at epoch 256 : 0.284249, Training Acc : 0.877930
# Training loss at epoch 257 : 0.283719, Training Acc : 0.886719
# Training loss at epoch 258 : 0.284626, Training Acc : 0.872070
# Training loss at epoch 259 : 0.281972, Training Acc : 0.876953
# Training loss at epoch 260 : 0.279907, Training Acc : 0.875977
# Training loss at epoch 261 : 0.282022, Training Acc : 0.874023
# Training loss at epoch 262 : 0.284502, Training Acc : 0.875977
# Training loss at epoch 263 : 0.280268, Training Acc : 0.875977
# Training loss at epoch 264 : 0.280479, Training Acc : 0.876953
# Training loss at epoch 265 : 0.282355, Training Acc : 0.877930
# Training loss at epoch 266 : 0.282287, Training Acc : 0.883789
# Training loss at epoch 267 : 0.281876, Training Acc : 0.886719
# Training loss at epoch 268 : 0.282583, Training Acc : 0.879883
# Training loss at epoch 269 : 0.282692, Training Acc : 0.883789
# Training loss at epoch 270 : 0.281071, Training Acc : 0.858398
# Training loss at epoch 271 : 0.281276, Training Acc : 0.870117
# Training loss at epoch 272 : 0.280675, Training Acc : 0.875977
# Training loss at epoch 273 : 0.279573, Training Acc : 0.874023
# Training loss at epoch 274 : 0.281694, Training Acc : 0.886719
# Training loss at epoch 275 : 0.282708, Training Acc : 0.875000
# Training loss at epoch 276 : 0.280714, Training Acc : 0.861328
# Training loss at epoch 277 : 0.280444, Training Acc : 0.884766
# Training loss at epoch 278 : 0.279891, Training Acc : 0.874023
# Training loss at epoch 279 : 0.281986, Training Acc : 0.881836
# Training loss at epoch 280 : 0.278186, Training Acc : 0.881836
# Training loss at epoch 281 : 0.283135, Training Acc : 0.874023
# Training loss at epoch 282 : 0.280698, Training Acc : 0.881836
# Training loss at epoch 283 : 0.278626, Training Acc : 0.880859
# Training loss at epoch 284 : 0.282937, Training Acc : 0.878906
# Training loss at epoch 285 : 0.287066, Training Acc : 0.880859
# Training loss at epoch 286 : 0.281133, Training Acc : 0.885742
# Training loss at epoch 287 : 0.280635, Training Acc : 0.874023
# Training loss at epoch 288 : 0.280255, Training Acc : 0.880859
# Training loss at epoch 289 : 0.284870, Training Acc : 0.877930
# Training loss at epoch 290 : 0.281958, Training Acc : 0.871094
# Training loss at epoch 291 : 0.280757, Training Acc : 0.883789
# Training loss at epoch 292 : 0.277000, Training Acc : 0.870117
# Training loss at epoch 293 : 0.279810, Training Acc : 0.877930
# Training loss at epoch 294 : 0.281946, Training Acc : 0.878906
# Training loss at epoch 295 : 0.279948, Training Acc : 0.875977
# Training loss at epoch 296 : 0.278668, Training Acc : 0.887695
# Training loss at epoch 297 : 0.281272, Training Acc : 0.875000
# Training loss at epoch 298 : 0.284405, Training Acc : 0.883789
# Training loss at epoch 299 : 0.278331, Training Acc : 0.878906
# Training loss at epoch 300 : 0.280296, Training Acc : 0.858398
# Training loss at epoch 301 : 0.281920, Training Acc : 0.885742
# Training loss at epoch 302 : 0.278824, Training Acc : 0.875000
# Training loss at epoch 303 : 0.277978, Training Acc : 0.880859
# Training loss at epoch 304 : 0.281201, Training Acc : 0.873047
# Training loss at epoch 305 : 0.281653, Training Acc : 0.875000
# Training loss at epoch 306 : 0.277137, Training Acc : 0.882812
# Training loss at epoch 307 : 0.284297, Training Acc : 0.887695
# Training loss at epoch 308 : 0.281451, Training Acc : 0.880859
# Training loss at epoch 309 : 0.279265, Training Acc : 0.875977
# Training loss at epoch 310 : 0.280796, Training Acc : 0.879883
# Training loss at epoch 311 : 0.277853, Training Acc : 0.873047
# Training loss at epoch 312 : 0.283727, Training Acc : 0.871094
# Training loss at epoch 313 : 0.282196, Training Acc : 0.875977
# Training loss at epoch 314 : 0.279308, Training Acc : 0.874023
# Training loss at epoch 315 : 0.281604, Training Acc : 0.862305
# Training loss at epoch 316 : 0.279822, Training Acc : 0.875977
# Training loss at epoch 317 : 0.280351, Training Acc : 0.888672
# Training loss at epoch 318 : 0.275059, Training Acc : 0.888672
# Training loss at epoch 319 : 0.280534, Training Acc : 0.876953
# Training loss at epoch 320 : 0.278068, Training Acc : 0.868164
# Training loss at epoch 321 : 0.276996, Training Acc : 0.877930
# Training loss at epoch 322 : 0.280361, Training Acc : 0.877930
# Training loss at epoch 323 : 0.280223, Training Acc : 0.866211
# Training loss at epoch 324 : 0.280510, Training Acc : 0.868164
# Training loss at epoch 325 : 0.280680, Training Acc : 0.876953
# Training loss at epoch 326 : 0.277493, Training Acc : 0.887695
# Training loss at epoch 327 : 0.279485, Training Acc : 0.885742
# Training loss at epoch 328 : 0.282185, Training Acc : 0.880859
# Training loss at epoch 329 : 0.278153, Training Acc : 0.870117
# Training loss at epoch 330 : 0.281773, Training Acc : 0.875000
# Training loss at epoch 331 : 0.282318, Training Acc : 0.890625
# Training loss at epoch 332 : 0.279380, Training Acc : 0.879883
# Training loss at epoch 333 : 0.280838, Training Acc : 0.875000
# Training loss at epoch 334 : 0.280980, Training Acc : 0.884766
# Training loss at epoch 335 : 0.281421, Training Acc : 0.857422
# Training loss at epoch 336 : 0.277168, Training Acc : 0.886719
# Training loss at epoch 337 : 0.278343, Training Acc : 0.883789
# Training loss at epoch 338 : 0.277641, Training Acc : 0.876953
# Training loss at epoch 339 : 0.276151, Training Acc : 0.863281
# Training loss at epoch 340 : 0.280540, Training Acc : 0.865234
# Training loss at epoch 341 : 0.276790, Training Acc : 0.867188
# Training loss at epoch 342 : 0.280111, Training Acc : 0.883789
# Training loss at epoch 343 : 0.281953, Training Acc : 0.873047
# Training loss at epoch 344 : 0.274656, Training Acc : 0.861328
# Training loss at epoch 345 : 0.280492, Training Acc : 0.863281
# Training loss at epoch 346 : 0.278874, Training Acc : 0.891602
# Training loss at epoch 347 : 0.280642, Training Acc : 0.862305
# Training loss at epoch 348 : 0.279119, Training Acc : 0.875977
# Training loss at epoch 349 : 0.276510, Training Acc : 0.886719
# Training loss at epoch 350 : 0.277308, Training Acc : 0.878906
# Training loss at epoch 351 : 0.276784, Training Acc : 0.875977
# Training loss at epoch 352 : 0.278285, Training Acc : 0.874023
# Training loss at epoch 353 : 0.277469, Training Acc : 0.878906
# Training loss at epoch 354 : 0.276429, Training Acc : 0.871094
# Training loss at epoch 355 : 0.280370, Training Acc : 0.878906
# Training loss at epoch 356 : 0.280200, Training Acc : 0.866211
# Training loss at epoch 357 : 0.277704, Training Acc : 0.876953
# Training loss at epoch 358 : 0.277397, Training Acc : 0.885742
# Training loss at epoch 359 : 0.274528, Training Acc : 0.881836
# Training loss at epoch 360 : 0.279316, Training Acc : 0.881836
# Training loss at epoch 361 : 0.277789, Training Acc : 0.873047
# Training loss at epoch 362 : 0.275299, Training Acc : 0.874023
# Training loss at epoch 363 : 0.276046, Training Acc : 0.877930
# Training loss at epoch 364 : 0.278377, Training Acc : 0.880859
# Training loss at epoch 365 : 0.275208, Training Acc : 0.876953
# Training loss at epoch 366 : 0.277470, Training Acc : 0.879883
# Training loss at epoch 367 : 0.278419, Training Acc : 0.880859
# Training loss at epoch 368 : 0.279076, Training Acc : 0.860352
# Training loss at epoch 369 : 0.274205, Training Acc : 0.873047
# Training loss at epoch 370 : 0.275661, Training Acc : 0.878906
# Training loss at epoch 371 : 0.275917, Training Acc : 0.884766
# Training loss at epoch 372 : 0.277594, Training Acc : 0.859375
# Training loss at epoch 373 : 0.277289, Training Acc : 0.883789
# Training loss at epoch 374 : 0.278798, Training Acc : 0.879883
# Training loss at epoch 375 : 0.279105, Training Acc : 0.887695
# Training loss at epoch 376 : 0.277724, Training Acc : 0.865234
# Training loss at epoch 377 : 0.277675, Training Acc : 0.869141
# Training loss at epoch 378 : 0.273276, Training Acc : 0.871094
# Training loss at epoch 379 : 0.277326, Training Acc : 0.881836
# Training loss at epoch 380 : 0.277720, Training Acc : 0.887695
# Training loss at epoch 381 : 0.278582, Training Acc : 0.880859
# Training loss at epoch 382 : 0.277499, Training Acc : 0.876953
# Training loss at epoch 383 : 0.280896, Training Acc : 0.882812
# Training loss at epoch 384 : 0.276975, Training Acc : 0.872070
# Training loss at epoch 385 : 0.277646, Training Acc : 0.876953
# Training loss at epoch 386 : 0.277790, Training Acc : 0.875000
# Training loss at epoch 387 : 0.275455, Training Acc : 0.882812
# Training loss at epoch 388 : 0.275622, Training Acc : 0.886719
# Training loss at epoch 389 : 0.282738, Training Acc : 0.886719
# Training loss at epoch 390 : 0.279912, Training Acc : 0.860352
# Training loss at epoch 391 : 0.274830, Training Acc : 0.883789
# Training loss at epoch 392 : 0.278339, Training Acc : 0.877930
# Training loss at epoch 393 : 0.277941, Training Acc : 0.860352
# Training loss at epoch 394 : 0.273102, Training Acc : 0.875977
# Training loss at epoch 395 : 0.279131, Training Acc : 0.871094
# Training loss at epoch 396 : 0.275416, Training Acc : 0.862305
# Training loss at epoch 397 : 0.279577, Training Acc : 0.890625
# Training loss at epoch 398 : 0.279987, Training Acc : 0.869141
# Training loss at epoch 399 : 0.276253, Training Acc : 0.880859
# Training loss at epoch 400 : 0.274078, Training Acc : 0.869141
# Training loss at epoch 401 : 0.278198, Training Acc : 0.854492
# Training loss at epoch 402 : 0.276962, Training Acc : 0.875000
# Training loss at epoch 403 : 0.278559, Training Acc : 0.885742
# Training loss at epoch 404 : 0.279855, Training Acc : 0.877930
# Training loss at epoch 405 : 0.277763, Training Acc : 0.874023
# Training loss at epoch 406 : 0.274383, Training Acc : 0.870117
# Training loss at epoch 407 : 0.274569, Training Acc : 0.886719
# Training loss at epoch 408 : 0.276519, Training Acc : 0.890625
# Training loss at epoch 409 : 0.276895, Training Acc : 0.879883
# Training loss at epoch 410 : 0.280054, Training Acc : 0.884766
# Training loss at epoch 411 : 0.273285, Training Acc : 0.873047
# Training loss at epoch 412 : 0.279638, Training Acc : 0.865234
# Training loss at epoch 413 : 0.276273, Training Acc : 0.874023
# Training loss at epoch 414 : 0.275718, Training Acc : 0.875977
# Training loss at epoch 415 : 0.275492, Training Acc : 0.855469
# Training loss at epoch 416 : 0.276910, Training Acc : 0.864258
# Training loss at epoch 417 : 0.275797, Training Acc : 0.879883
# Training loss at epoch 418 : 0.275490, Training Acc : 0.863281
# Training loss at epoch 419 : 0.272434, Training Acc : 0.886719
# Training loss at epoch 420 : 0.275066, Training Acc : 0.881836
# Training loss at epoch 421 : 0.275621, Training Acc : 0.885742
# Training loss at epoch 422 : 0.275477, Training Acc : 0.877930
# Training loss at epoch 423 : 0.276107, Training Acc : 0.875000
# Training loss at epoch 424 : 0.278275, Training Acc : 0.882812
# Training loss at epoch 425 : 0.277249, Training Acc : 0.877930
# Training loss at epoch 426 : 0.278504, Training Acc : 0.880859
# Training loss at epoch 427 : 0.275031, Training Acc : 0.879883
# Training loss at epoch 428 : 0.278034, Training Acc : 0.869141
# Training loss at epoch 429 : 0.275869, Training Acc : 0.881836
# Training loss at epoch 430 : 0.275808, Training Acc : 0.889648
# Training loss at epoch 431 : 0.276906, Training Acc : 0.875977
# Training loss at epoch 432 : 0.275335, Training Acc : 0.894531
# Training loss at epoch 433 : 0.274027, Training Acc : 0.889648
# Training loss at epoch 434 : 0.275247, Training Acc : 0.875977
# Training loss at epoch 435 : 0.274102, Training Acc : 0.886719
# Training loss at epoch 436 : 0.273569, Training Acc : 0.878906
# Training loss at epoch 437 : 0.275724, Training Acc : 0.869141
# Training loss at epoch 438 : 0.274811, Training Acc : 0.869141
# Training loss at epoch 439 : 0.274102, Training Acc : 0.877930
# Training loss at epoch 440 : 0.276112, Training Acc : 0.883789
# Training loss at epoch 441 : 0.275832, Training Acc : 0.865234
# Training loss at epoch 442 : 0.275737, Training Acc : 0.880859
# Training loss at epoch 443 : 0.273650, Training Acc : 0.862305
# Training loss at epoch 444 : 0.273677, Training Acc : 0.878906
# Training loss at epoch 445 : 0.273331, Training Acc : 0.879883
# Training loss at epoch 446 : 0.276178, Training Acc : 0.856445
# Training loss at epoch 447 : 0.274101, Training Acc : 0.878906
# Training loss at epoch 448 : 0.274871, Training Acc : 0.886719
# Training loss at epoch 449 : 0.273237, Training Acc : 0.879883
# Training loss at epoch 450 : 0.275532, Training Acc : 0.858398
# Training loss at epoch 451 : 0.276041, Training Acc : 0.865234
# Training loss at epoch 452 : 0.275635, Training Acc : 0.859375
# Training loss at epoch 453 : 0.272911, Training Acc : 0.876953
# Training loss at epoch 454 : 0.274917, Training Acc : 0.870117
# Training loss at epoch 455 : 0.276034, Training Acc : 0.861328
# Training loss at epoch 456 : 0.276555, Training Acc : 0.882812
# Training loss at epoch 457 : 0.274323, Training Acc : 0.881836
# Training loss at epoch 458 : 0.274731, Training Acc : 0.883789
# Training loss at epoch 459 : 0.276788, Training Acc : 0.876953
# Training loss at epoch 460 : 0.274644, Training Acc : 0.875000
# Training loss at epoch 461 : 0.275900, Training Acc : 0.881836
# Training loss at epoch 462 : 0.275375, Training Acc : 0.875000
# Training loss at epoch 463 : 0.273401, Training Acc : 0.876953
# Training loss at epoch 464 : 0.273849, Training Acc : 0.881836
# Training loss at epoch 465 : 0.275760, Training Acc : 0.882812
# Training loss at epoch 466 : 0.275630, Training Acc : 0.876953
# Training loss at epoch 467 : 0.273671, Training Acc : 0.867188
# Training loss at epoch 468 : 0.273184, Training Acc : 0.875000
# Training loss at epoch 469 : 0.271837, Training Acc : 0.871094
# Training loss at epoch 470 : 0.275874, Training Acc : 0.880859
# Training loss at epoch 471 : 0.274636, Training Acc : 0.888672
# Training loss at epoch 472 : 0.275149, Training Acc : 0.870117
# Training loss at epoch 473 : 0.275137, Training Acc : 0.877930
# Training loss at epoch 474 : 0.273828, Training Acc : 0.876953
# Training loss at epoch 475 : 0.274645, Training Acc : 0.884766
# Training loss at epoch 476 : 0.276159, Training Acc : 0.872070
# Training loss at epoch 477 : 0.276640, Training Acc : 0.871094
# Training loss at epoch 478 : 0.276301, Training Acc : 0.872070
# Training loss at epoch 479 : 0.277617, Training Acc : 0.883789
# Training loss at epoch 480 : 0.275166, Training Acc : 0.878906
# Training loss at epoch 481 : 0.277952, Training Acc : 0.863281
# Training loss at epoch 482 : 0.273037, Training Acc : 0.871094
# Training loss at epoch 483 : 0.274062, Training Acc : 0.876953
# Training loss at epoch 484 : 0.273862, Training Acc : 0.872070
# Training loss at epoch 485 : 0.277085, Training Acc : 0.877930
# Training loss at epoch 486 : 0.276589, Training Acc : 0.856445
# Training loss at epoch 487 : 0.278742, Training Acc : 0.871094
# Training loss at epoch 488 : 0.273430, Training Acc : 0.879883
# Training loss at epoch 489 : 0.274915, Training Acc : 0.876953
# Training loss at epoch 490 : 0.275147, Training Acc : 0.885742
# Training loss at epoch 491 : 0.273817, Training Acc : 0.872070
# Training loss at epoch 492 : 0.270745, Training Acc : 0.879883
# Training loss at epoch 493 : 0.277308, Training Acc : 0.871094
# Training loss at epoch 494 : 0.275495, Training Acc : 0.882812
# Training loss at epoch 495 : 0.275082, Training Acc : 0.881836
# Training loss at epoch 496 : 0.277966, Training Acc : 0.874023
# Training loss at epoch 497 : 0.274539, Training Acc : 0.870117
# Training loss at epoch 498 : 0.275064, Training Acc : 0.874023
# Training loss at epoch 499 : 0.274727, Training Acc : 0.883789
# Training loss at epoch 500 : 0.276144, Training Acc : 0.881836
# Training loss at epoch 501 : 0.275762, Training Acc : 0.872070
# Training loss at epoch 502 : 0.277416, Training Acc : 0.879883
# Training loss at epoch 503 : 0.274181, Training Acc : 0.879883
# Training loss at epoch 504 : 0.275430, Training Acc : 0.870117
# Training loss at epoch 505 : 0.276753, Training Acc : 0.878906
# Training loss at epoch 506 : 0.273300, Training Acc : 0.860352
# Training loss at epoch 507 : 0.273911, Training Acc : 0.875000
# Training loss at epoch 508 : 0.276263, Training Acc : 0.862305
# Training loss at epoch 509 : 0.273203, Training Acc : 0.875000
# Training loss at epoch 510 : 0.273421, Training Acc : 0.870117
# Training loss at epoch 511 : 0.272108, Training Acc : 0.885742
# Training loss at epoch 512 : 0.276799, Training Acc : 0.868164
# Training loss at epoch 513 : 0.275715, Training Acc : 0.874023
# Training loss at epoch 514 : 0.275906, Training Acc : 0.874023
# Training loss at epoch 515 : 0.274889, Training Acc : 0.877930
# Training loss at epoch 516 : 0.272083, Training Acc : 0.870117
# Training loss at epoch 517 : 0.271459, Training Acc : 0.876953
# Training loss at epoch 518 : 0.275050, Training Acc : 0.884766
# Training loss at epoch 519 : 0.270190, Training Acc : 0.868164
# Training loss at epoch 520 : 0.273965, Training Acc : 0.879883
# Training loss at epoch 521 : 0.272339, Training Acc : 0.871094
# Training loss at epoch 522 : 0.273939, Training Acc : 0.875977
# Training loss at epoch 523 : 0.274680, Training Acc : 0.883789
# Training loss at epoch 524 : 0.273638, Training Acc : 0.880859
# Training loss at epoch 525 : 0.273348, Training Acc : 0.874023
# Training loss at epoch 526 : 0.272692, Training Acc : 0.875977
# Training loss at epoch 527 : 0.277022, Training Acc : 0.868164
# Training loss at epoch 528 : 0.276081, Training Acc : 0.871094
# Training loss at epoch 529 : 0.274768, Training Acc : 0.865234
# Training loss at epoch 530 : 0.277715, Training Acc : 0.875000
# Training loss at epoch 531 : 0.274427, Training Acc : 0.881836
# Training loss at epoch 532 : 0.273305, Training Acc : 0.866211
# Training loss at epoch 533 : 0.273920, Training Acc : 0.873047
# Training loss at epoch 534 : 0.273673, Training Acc : 0.883789
# Training loss at epoch 535 : 0.272623, Training Acc : 0.881836
# Training loss at epoch 536 : 0.271866, Training Acc : 0.891602
# Training loss at epoch 537 : 0.272848, Training Acc : 0.878906
# Training loss at epoch 538 : 0.277338, Training Acc : 0.859375
# Training loss at epoch 539 : 0.272822, Training Acc : 0.876953
# Training loss at epoch 540 : 0.275174, Training Acc : 0.875977
# Training loss at epoch 541 : 0.272844, Training Acc : 0.887695
# Training loss at epoch 542 : 0.273823, Training Acc : 0.876953
# Training loss at epoch 543 : 0.271519, Training Acc : 0.868164
# Training loss at epoch 544 : 0.273454, Training Acc : 0.872070
# Training loss at epoch 545 : 0.273309, Training Acc : 0.871094
# Training loss at epoch 546 : 0.272475, Training Acc : 0.872070
# Training loss at epoch 547 : 0.271547, Training Acc : 0.875977
# Training loss at epoch 548 : 0.275627, Training Acc : 0.873047
# Training loss at epoch 549 : 0.274540, Training Acc : 0.874023
# Training loss at epoch 550 : 0.274151, Training Acc : 0.891602
# Training loss at epoch 551 : 0.275606, Training Acc : 0.878906
# Training loss at epoch 552 : 0.275196, Training Acc : 0.884766
# Training loss at epoch 553 : 0.276197, Training Acc : 0.867188
# Training loss at epoch 554 : 0.272360, Training Acc : 0.884766
# Training loss at epoch 555 : 0.276362, Training Acc : 0.878906
# Training loss at epoch 556 : 0.275409, Training Acc : 0.884766
# Training loss at epoch 557 : 0.272934, Training Acc : 0.868164
# Training loss at epoch 558 : 0.270128, Training Acc : 0.869141
# Training loss at epoch 559 : 0.276551, Training Acc : 0.886719
# Training loss at epoch 560 : 0.272032, Training Acc : 0.875977
# Training loss at epoch 561 : 0.274530, Training Acc : 0.871094
# Training loss at epoch 562 : 0.276032, Training Acc : 0.871094
# Training loss at epoch 563 : 0.273464, Training Acc : 0.882812
# Training loss at epoch 564 : 0.273053, Training Acc : 0.882812
# Training loss at epoch 565 : 0.275148, Training Acc : 0.876953
# Training loss at epoch 566 : 0.273643, Training Acc : 0.886719
# Training loss at epoch 567 : 0.273182, Training Acc : 0.877930
# Training loss at epoch 568 : 0.272007, Training Acc : 0.876953
# Training loss at epoch 569 : 0.274213, Training Acc : 0.883789
# Training loss at epoch 570 : 0.271253, Training Acc : 0.875977
# Training loss at epoch 571 : 0.273832, Training Acc : 0.884766
# Training loss at epoch 572 : 0.274683, Training Acc : 0.887695
# Training loss at epoch 573 : 0.271143, Training Acc : 0.875000
# Training loss at epoch 574 : 0.270949, Training Acc : 0.882812
# Training loss at epoch 575 : 0.271252, Training Acc : 0.876953
# Training loss at epoch 576 : 0.269494, Training Acc : 0.881836
# Training loss at epoch 577 : 0.273252, Training Acc : 0.877930
# Training loss at epoch 578 : 0.273359, Training Acc : 0.881836
# Training loss at epoch 579 : 0.273165, Training Acc : 0.876953
# Training loss at epoch 580 : 0.274570, Training Acc : 0.872070
# Training loss at epoch 581 : 0.272521, Training Acc : 0.876953
# Training loss at epoch 582 : 0.272070, Training Acc : 0.884766
# Training loss at epoch 583 : 0.272651, Training Acc : 0.885742
# Training loss at epoch 584 : 0.274016, Training Acc : 0.873047
# Training loss at epoch 585 : 0.270289, Training Acc : 0.876953
# Training loss at epoch 586 : 0.272223, Training Acc : 0.884766
# Training loss at epoch 587 : 0.273195, Training Acc : 0.890625
# Training loss at epoch 588 : 0.271818, Training Acc : 0.874023
# Training loss at epoch 589 : 0.270142, Training Acc : 0.871094
# Training loss at epoch 590 : 0.274728, Training Acc : 0.871094
# Training loss at epoch 591 : 0.268323, Training Acc : 0.884766
# Training loss at epoch 592 : 0.274392, Training Acc : 0.875977
# Training loss at epoch 593 : 0.272388, Training Acc : 0.887695
# Training loss at epoch 594 : 0.270148, Training Acc : 0.873047
# Training loss at epoch 595 : 0.273406, Training Acc : 0.871094
# Training loss at epoch 596 : 0.272777, Training Acc : 0.875000
# Training loss at epoch 597 : 0.271608, Training Acc : 0.878906
# Training loss at epoch 598 : 0.272454, Training Acc : 0.875000
# Training loss at epoch 599 : 0.270726, Training Acc : 0.879883
# Training loss at epoch 600 : 0.272953, Training Acc : 0.872070
# Training loss at epoch 601 : 0.271510, Training Acc : 0.868164
# Training loss at epoch 602 : 0.273111, Training Acc : 0.883789
# Training loss at epoch 603 : 0.271418, Training Acc : 0.871094
# Training loss at epoch 604 : 0.273750, Training Acc : 0.870117
# Training loss at epoch 605 : 0.271819, Training Acc : 0.887695
# Training loss at epoch 606 : 0.270453, Training Acc : 0.877930
# Training loss at epoch 607 : 0.271211, Training Acc : 0.874023
# Training loss at epoch 608 : 0.272149, Training Acc : 0.869141
# Training loss at epoch 609 : 0.269269, Training Acc : 0.888672
# Training loss at epoch 610 : 0.270880, Training Acc : 0.876953
# Training loss at epoch 611 : 0.270471, Training Acc : 0.866211
# Training loss at epoch 612 : 0.273017, Training Acc : 0.868164
# Training loss at epoch 613 : 0.273931, Training Acc : 0.887695
# Training loss at epoch 614 : 0.269931, Training Acc : 0.874023
# Training loss at epoch 615 : 0.273773, Training Acc : 0.876953
# Training loss at epoch 616 : 0.271083, Training Acc : 0.875977
# Training loss at epoch 617 : 0.272805, Training Acc : 0.874023
# Training loss at epoch 618 : 0.272937, Training Acc : 0.883789
# Training loss at epoch 619 : 0.273223, Training Acc : 0.872070
# Training loss at epoch 620 : 0.272313, Training Acc : 0.887695
# Training loss at epoch 621 : 0.273178, Training Acc : 0.877930
# Training loss at epoch 622 : 0.272334, Training Acc : 0.877930
# Training loss at epoch 623 : 0.271317, Training Acc : 0.887695
# Training loss at epoch 624 : 0.270499, Training Acc : 0.879883
# Training loss at epoch 625 : 0.272922, Training Acc : 0.877930
# Training loss at epoch 626 : 0.275214, Training Acc : 0.874023
# Training loss at epoch 627 : 0.274783, Training Acc : 0.881836
# Training loss at epoch 628 : 0.273078, Training Acc : 0.878906
# Training loss at epoch 629 : 0.269028, Training Acc : 0.887695
# Training loss at epoch 630 : 0.274378, Training Acc : 0.882812
# Training loss at epoch 631 : 0.270347, Training Acc : 0.876953
# Training loss at epoch 632 : 0.272293, Training Acc : 0.870117
# Training loss at epoch 633 : 0.272315, Training Acc : 0.862305
# Training loss at epoch 634 : 0.272875, Training Acc : 0.876953
# Training loss at epoch 635 : 0.268263, Training Acc : 0.881836
# Training loss at epoch 636 : 0.268660, Training Acc : 0.865234
# Training loss at epoch 637 : 0.270988, Training Acc : 0.875000
# Training loss at epoch 638 : 0.272468, Training Acc : 0.868164
# Training loss at epoch 639 : 0.273094, Training Acc : 0.885742
# Training loss at epoch 640 : 0.270665, Training Acc : 0.859375
# Training loss at epoch 641 : 0.268964, Training Acc : 0.883789
# Training loss at epoch 642 : 0.271622, Training Acc : 0.867188
# Training loss at epoch 643 : 0.272918, Training Acc : 0.879883
# Training loss at epoch 644 : 0.273244, Training Acc : 0.878906
# Training loss at epoch 645 : 0.272362, Training Acc : 0.881836
# Training loss at epoch 646 : 0.270938, Training Acc : 0.881836
# Training loss at epoch 647 : 0.270709, Training Acc : 0.860352
# Training loss at epoch 648 : 0.271339, Training Acc : 0.879883
# Training loss at epoch 649 : 0.275393, Training Acc : 0.875977
# Training loss at epoch 650 : 0.272939, Training Acc : 0.877930
# Training loss at epoch 651 : 0.271114, Training Acc : 0.877930
# Training loss at epoch 652 : 0.271079, Training Acc : 0.885742
# Training loss at epoch 653 : 0.271947, Training Acc : 0.877930
# Training loss at epoch 654 : 0.270608, Training Acc : 0.863281
# Training loss at epoch 655 : 0.271243, Training Acc : 0.886719
# Training loss at epoch 656 : 0.271241, Training Acc : 0.867188
# Training loss at epoch 657 : 0.267824, Training Acc : 0.885742
# Training loss at epoch 658 : 0.270625, Training Acc : 0.883789
# Training loss at epoch 659 : 0.272442, Training Acc : 0.869141
# Training loss at epoch 660 : 0.274467, Training Acc : 0.877930
# Training loss at epoch 661 : 0.273378, Training Acc : 0.855469
# Training loss at epoch 662 : 0.271541, Training Acc : 0.883789
# Training loss at epoch 663 : 0.272303, Training Acc : 0.875000
# Training loss at epoch 664 : 0.273879, Training Acc : 0.870117
# Training loss at epoch 665 : 0.272457, Training Acc : 0.885742
# Training loss at epoch 666 : 0.274681, Training Acc : 0.878906
# Training loss at epoch 667 : 0.269605, Training Acc : 0.887695
# Training loss at epoch 668 : 0.271070, Training Acc : 0.877930
# Training loss at epoch 669 : 0.272264, Training Acc : 0.883789
# Training loss at epoch 670 : 0.272854, Training Acc : 0.875977
# Training loss at epoch 671 : 0.272886, Training Acc : 0.866211
# Training loss at epoch 672 : 0.274208, Training Acc : 0.878906
# Training loss at epoch 673 : 0.270593, Training Acc : 0.873047
# Training loss at epoch 674 : 0.272521, Training Acc : 0.875977
# Training loss at epoch 675 : 0.273119, Training Acc : 0.874023
# Training loss at epoch 676 : 0.269787, Training Acc : 0.884766
# Training loss at epoch 677 : 0.271438, Training Acc : 0.878906
# Training loss at epoch 678 : 0.271711, Training Acc : 0.876953
# Training loss at epoch 679 : 0.271456, Training Acc : 0.872070
# Training loss at epoch 680 : 0.269933, Training Acc : 0.872070
# Training loss at epoch 681 : 0.271480, Training Acc : 0.875977
# Training loss at epoch 682 : 0.269046, Training Acc : 0.881836
# Training loss at epoch 683 : 0.270590, Training Acc : 0.874023
# Training loss at epoch 684 : 0.273163, Training Acc : 0.875977
# Training loss at epoch 685 : 0.270157, Training Acc : 0.875977
# Training loss at epoch 686 : 0.270846, Training Acc : 0.883789
# Training loss at epoch 687 : 0.269894, Training Acc : 0.863281
# Training loss at epoch 688 : 0.270696, Training Acc : 0.876953
# Training loss at epoch 689 : 0.266295, Training Acc : 0.884766
# Training loss at epoch 690 : 0.270760, Training Acc : 0.868164
# Training loss at epoch 691 : 0.270145, Training Acc : 0.886719
# Training loss at epoch 692 : 0.271776, Training Acc : 0.882812
# Training loss at epoch 693 : 0.271877, Training Acc : 0.880859
# Training loss at epoch 694 : 0.270856, Training Acc : 0.872070
# Training loss at epoch 695 : 0.269857, Training Acc : 0.866211
# Training loss at epoch 696 : 0.270389, Training Acc : 0.875977
# Training loss at epoch 697 : 0.271957, Training Acc : 0.881836
# Training loss at epoch 698 : 0.270882, Training Acc : 0.885742
# Training loss at epoch 699 : 0.273005, Training Acc : 0.885742
# Training loss at epoch 700 : 0.272071, Training Acc : 0.881836
# Training loss at epoch 701 : 0.271610, Training Acc : 0.869141
# Training loss at epoch 702 : 0.270303, Training Acc : 0.875000
# Training loss at epoch 703 : 0.272363, Training Acc : 0.870117
# Training loss at epoch 704 : 0.268548, Training Acc : 0.880859
# Training loss at epoch 705 : 0.270873, Training Acc : 0.886719
# Training loss at epoch 706 : 0.267987, Training Acc : 0.882812
# Training loss at epoch 707 : 0.269047, Training Acc : 0.879883
# Training loss at epoch 708 : 0.272284, Training Acc : 0.887695
# Training loss at epoch 709 : 0.267922, Training Acc : 0.881836
# Training loss at epoch 710 : 0.269103, Training Acc : 0.878906
# Training loss at epoch 711 : 0.271587, Training Acc : 0.884766
# Training loss at epoch 712 : 0.269997, Training Acc : 0.883789
# Training loss at epoch 713 : 0.270541, Training Acc : 0.871094
# Training loss at epoch 714 : 0.271820, Training Acc : 0.874023
# Training loss at epoch 715 : 0.270824, Training Acc : 0.880859
# Training loss at epoch 716 : 0.271042, Training Acc : 0.874023
# Training loss at epoch 717 : 0.267789, Training Acc : 0.883789
# Training loss at epoch 718 : 0.272324, Training Acc : 0.868164
# Training loss at epoch 719 : 0.269812, Training Acc : 0.878906
# Training loss at epoch 720 : 0.268798, Training Acc : 0.867188
# Training loss at epoch 721 : 0.274806, Training Acc : 0.868164
# Training loss at epoch 722 : 0.270911, Training Acc : 0.868164
# Training loss at epoch 723 : 0.270526, Training Acc : 0.875000
# Training loss at epoch 724 : 0.273696, Training Acc : 0.874023
# Training loss at epoch 725 : 0.270286, Training Acc : 0.881836
# Training loss at epoch 726 : 0.272505, Training Acc : 0.880859
# Training loss at epoch 727 : 0.268673, Training Acc : 0.876953
# Training loss at epoch 728 : 0.268932, Training Acc : 0.885742
# Training loss at epoch 729 : 0.271614, Training Acc : 0.884766
# Training loss at epoch 730 : 0.270238, Training Acc : 0.885742
# Training loss at epoch 731 : 0.273185, Training Acc : 0.880859
# Training loss at epoch 732 : 0.268965, Training Acc : 0.881836
# Training loss at epoch 733 : 0.270791, Training Acc : 0.862305
# Training loss at epoch 734 : 0.269754, Training Acc : 0.886719
# Training loss at epoch 735 : 0.273042, Training Acc : 0.880859
# Training loss at epoch 736 : 0.267910, Training Acc : 0.886719
# Training loss at epoch 737 : 0.267833, Training Acc : 0.883789
# Training loss at epoch 738 : 0.271020, Training Acc : 0.875977
# Training loss at epoch 739 : 0.270963, Training Acc : 0.870117
# Training loss at epoch 740 : 0.266811, Training Acc : 0.881836
# Training loss at epoch 741 : 0.267628, Training Acc : 0.874023
# Training loss at epoch 742 : 0.270723, Training Acc : 0.873047
# Training loss at epoch 743 : 0.270111, Training Acc : 0.871094
# Training loss at epoch 744 : 0.270801, Training Acc : 0.869141
# Training loss at epoch 745 : 0.267857, Training Acc : 0.870117
# Training loss at epoch 746 : 0.272709, Training Acc : 0.884766
# Training loss at epoch 747 : 0.269589, Training Acc : 0.884766
# Training loss at epoch 748 : 0.269136, Training Acc : 0.880859
# Training loss at epoch 749 : 0.265564, Training Acc : 0.883789
# Training loss at epoch 750 : 0.268776, Training Acc : 0.875977
# Training loss at epoch 751 : 0.270444, Training Acc : 0.869141
# Training loss at epoch 752 : 0.268308, Training Acc : 0.885742
# Training loss at epoch 753 : 0.270305, Training Acc : 0.887695
# Training loss at epoch 754 : 0.266860, Training Acc : 0.872070
# Training loss at epoch 755 : 0.268731, Training Acc : 0.877930
# Training loss at epoch 756 : 0.267459, Training Acc : 0.872070
# Training loss at epoch 757 : 0.270902, Training Acc : 0.889648
# Training loss at epoch 758 : 0.272486, Training Acc : 0.870117
# Training loss at epoch 759 : 0.269424, Training Acc : 0.869141
# Training loss at epoch 760 : 0.267041, Training Acc : 0.885742
# Training loss at epoch 761 : 0.272603, Training Acc : 0.875000
# Training loss at epoch 762 : 0.269396, Training Acc : 0.875977
# Training loss at epoch 763 : 0.268939, Training Acc : 0.882812
# Training loss at epoch 764 : 0.271679, Training Acc : 0.882812
# Training loss at epoch 765 : 0.269778, Training Acc : 0.883789
# Training loss at epoch 766 : 0.271237, Training Acc : 0.863281
# Training loss at epoch 767 : 0.271083, Training Acc : 0.875977
# Training loss at epoch 768 : 0.270278, Training Acc : 0.878906
# Training loss at epoch 769 : 0.266791, Training Acc : 0.883789
# Training loss at epoch 770 : 0.269259, Training Acc : 0.875000
# Training loss at epoch 771 : 0.271651, Training Acc : 0.875977
# Training loss at epoch 772 : 0.268866, Training Acc : 0.849609
# Training loss at epoch 773 : 0.268987, Training Acc : 0.866211
# Training loss at epoch 774 : 0.269483, Training Acc : 0.870117
# Training loss at epoch 775 : 0.270705, Training Acc : 0.886719
# Training loss at epoch 776 : 0.268102, Training Acc : 0.879883
# Training loss at epoch 777 : 0.269822, Training Acc : 0.871094
# Training loss at epoch 778 : 0.269613, Training Acc : 0.877930
# Training loss at epoch 779 : 0.269120, Training Acc : 0.884766
# Training loss at epoch 780 : 0.271608, Training Acc : 0.875000
# Training loss at epoch 781 : 0.268579, Training Acc : 0.875000
# Training loss at epoch 782 : 0.270325, Training Acc : 0.884766
# Training loss at epoch 783 : 0.269050, Training Acc : 0.885742
# Training loss at epoch 784 : 0.271281, Training Acc : 0.883789
# Training loss at epoch 785 : 0.269168, Training Acc : 0.886719
# Training loss at epoch 786 : 0.271245, Training Acc : 0.861328
# Training loss at epoch 787 : 0.269249, Training Acc : 0.876953
# Training loss at epoch 788 : 0.269160, Training Acc : 0.882812
# Training loss at epoch 789 : 0.271917, Training Acc : 0.882812
# Training loss at epoch 790 : 0.270210, Training Acc : 0.883789
# Training loss at epoch 791 : 0.269680, Training Acc : 0.882812
# Training loss at epoch 792 : 0.268532, Training Acc : 0.884766
# Training loss at epoch 793 : 0.267838, Training Acc : 0.880859
# Training loss at epoch 794 : 0.271208, Training Acc : 0.871094
# Training loss at epoch 795 : 0.268779, Training Acc : 0.881836
# Training loss at epoch 796 : 0.269062, Training Acc : 0.888672
# Training loss at epoch 797 : 0.268427, Training Acc : 0.877930
# Training loss at epoch 798 : 0.269182, Training Acc : 0.882812
# Training loss at epoch 799 : 0.265496, Training Acc : 0.876953
# Training loss at epoch 800 : 0.270242, Training Acc : 0.873047
# Training loss at epoch 801 : 0.268125, Training Acc : 0.884766
# Training loss at epoch 802 : 0.270299, Training Acc : 0.887695
# Training loss at epoch 803 : 0.268551, Training Acc : 0.876953
# Training loss at epoch 804 : 0.269330, Training Acc : 0.875977
# Training loss at epoch 805 : 0.271453, Training Acc : 0.875977
# Training loss at epoch 806 : 0.270226, Training Acc : 0.871094
# Training loss at epoch 807 : 0.270092, Training Acc : 0.865234
# Training loss at epoch 808 : 0.267852, Training Acc : 0.886719
# Training loss at epoch 809 : 0.267323, Training Acc : 0.874023
# Training loss at epoch 810 : 0.269732, Training Acc : 0.875000
# Training loss at epoch 811 : 0.269252, Training Acc : 0.887695
# Training loss at epoch 812 : 0.270068, Training Acc : 0.878906
# Training loss at epoch 813 : 0.271105, Training Acc : 0.875977
# Training loss at epoch 814 : 0.270990, Training Acc : 0.861328
# Training loss at epoch 815 : 0.267069, Training Acc : 0.880859
# Training loss at epoch 816 : 0.270729, Training Acc : 0.859375
# Training loss at epoch 817 : 0.271563, Training Acc : 0.865234
# Training loss at epoch 818 : 0.271247, Training Acc : 0.880859
# Training loss at epoch 819 : 0.270428, Training Acc : 0.875977
# Training loss at epoch 820 : 0.271029, Training Acc : 0.872070
# Training loss at epoch 821 : 0.264990, Training Acc : 0.878906
# Training loss at epoch 822 : 0.269234, Training Acc : 0.868164
# Training loss at epoch 823 : 0.265910, Training Acc : 0.884766
# Training loss at epoch 824 : 0.270222, Training Acc : 0.864258
# Training loss at epoch 825 : 0.270322, Training Acc : 0.875977
# Training loss at epoch 826 : 0.268949, Training Acc : 0.881836
# Training loss at epoch 827 : 0.268535, Training Acc : 0.886719
# Training loss at epoch 828 : 0.269478, Training Acc : 0.877930
# Training loss at epoch 829 : 0.268920, Training Acc : 0.881836
# Training loss at epoch 830 : 0.269987, Training Acc : 0.880859
# Training loss at epoch 831 : 0.270372, Training Acc : 0.869141
# Training loss at epoch 832 : 0.267289, Training Acc : 0.879883
# Training loss at epoch 833 : 0.268260, Training Acc : 0.875000
# Training loss at epoch 834 : 0.264729, Training Acc : 0.880859
# Training loss at epoch 835 : 0.265407, Training Acc : 0.877930
# Training loss at epoch 836 : 0.269172, Training Acc : 0.880859
# Training loss at epoch 837 : 0.267260, Training Acc : 0.874023
# Training loss at epoch 838 : 0.267465, Training Acc : 0.875977
# Training loss at epoch 839 : 0.268870, Training Acc : 0.884766
# Training loss at epoch 840 : 0.267351, Training Acc : 0.878906
# Training loss at epoch 841 : 0.268025, Training Acc : 0.879883
# Training loss at epoch 842 : 0.264588, Training Acc : 0.887695
# Training loss at epoch 843 : 0.266744, Training Acc : 0.875977
# Training loss at epoch 844 : 0.267217, Training Acc : 0.881836
# Training loss at epoch 845 : 0.266606, Training Acc : 0.887695
# Training loss at epoch 846 : 0.266732, Training Acc : 0.880859
# Training loss at epoch 847 : 0.267230, Training Acc : 0.865234
# Training loss at epoch 848 : 0.270003, Training Acc : 0.873047
# Training loss at epoch 849 : 0.268218, Training Acc : 0.883789
# Training loss at epoch 850 : 0.268961, Training Acc : 0.876953
# Training loss at epoch 851 : 0.267932, Training Acc : 0.876953
# Training loss at epoch 852 : 0.268335, Training Acc : 0.887695
# Training loss at epoch 853 : 0.268418, Training Acc : 0.863281
# Training loss at epoch 854 : 0.266066, Training Acc : 0.874023
# Training loss at epoch 855 : 0.267364, Training Acc : 0.885742
# Training loss at epoch 856 : 0.269631, Training Acc : 0.880859
# Training loss at epoch 857 : 0.270546, Training Acc : 0.870117
# Training loss at epoch 858 : 0.268886, Training Acc : 0.876953
# Training loss at epoch 859 : 0.265582, Training Acc : 0.880859
# Training loss at epoch 860 : 0.266353, Training Acc : 0.876953
# Training loss at epoch 861 : 0.267362, Training Acc : 0.875977
# Training loss at epoch 862 : 0.268296, Training Acc : 0.860352
# Training loss at epoch 863 : 0.266912, Training Acc : 0.877930
# Training loss at epoch 864 : 0.268748, Training Acc : 0.879883
# Training loss at epoch 865 : 0.269134, Training Acc : 0.862305
# Training loss at epoch 866 : 0.269262, Training Acc : 0.884766
# Training loss at epoch 867 : 0.269064, Training Acc : 0.882812
# Training loss at epoch 868 : 0.267299, Training Acc : 0.884766
# Training loss at epoch 869 : 0.266559, Training Acc : 0.885742
# Training loss at epoch 870 : 0.269224, Training Acc : 0.878906
# Training loss at epoch 871 : 0.267576, Training Acc : 0.879883
# Training loss at epoch 872 : 0.269061, Training Acc : 0.860352
# Training loss at epoch 873 : 0.267870, Training Acc : 0.878906
# Training loss at epoch 874 : 0.266254, Training Acc : 0.886719
# Training loss at epoch 875 : 0.268791, Training Acc : 0.868164
# Training loss at epoch 876 : 0.264696, Training Acc : 0.881836
# Training loss at epoch 877 : 0.267877, Training Acc : 0.875977
# Training loss at epoch 878 : 0.266725, Training Acc : 0.872070
# Training loss at epoch 879 : 0.268810, Training Acc : 0.876953
# Training loss at epoch 880 : 0.265720, Training Acc : 0.877930
# Training loss at epoch 881 : 0.271895, Training Acc : 0.880859
# Training loss at epoch 882 : 0.266263, Training Acc : 0.868164
# Training loss at epoch 883 : 0.267603, Training Acc : 0.875000
# Training loss at epoch 884 : 0.268065, Training Acc : 0.875977
# Training loss at epoch 885 : 0.270790, Training Acc : 0.875977
# Training loss at epoch 886 : 0.268077, Training Acc : 0.878906
# Training loss at epoch 887 : 0.267442, Training Acc : 0.875977
# Training loss at epoch 888 : 0.266094, Training Acc : 0.888672
# Training loss at epoch 889 : 0.267896, Training Acc : 0.883789
# Training loss at epoch 890 : 0.268350, Training Acc : 0.870117
# Training loss at epoch 891 : 0.265331, Training Acc : 0.883789
# Training loss at epoch 892 : 0.265010, Training Acc : 0.874023
# Training loss at epoch 893 : 0.267831, Training Acc : 0.867188
# Training loss at epoch 894 : 0.269747, Training Acc : 0.875977
# Training loss at epoch 895 : 0.267594, Training Acc : 0.882812
# Training loss at epoch 896 : 0.267218, Training Acc : 0.884766
# Training loss at epoch 897 : 0.268260, Training Acc : 0.874023
# Training loss at epoch 898 : 0.266504, Training Acc : 0.888672
# Training loss at epoch 899 : 0.270079, Training Acc : 0.886719
# Training loss at epoch 900 : 0.267407, Training Acc : 0.871094
# Training loss at epoch 901 : 0.266408, Training Acc : 0.877930
# Training loss at epoch 902 : 0.270264, Training Acc : 0.875977
# Training loss at epoch 903 : 0.267410, Training Acc : 0.862305
# Training loss at epoch 904 : 0.266618, Training Acc : 0.869141
# Training loss at epoch 905 : 0.266516, Training Acc : 0.877930
# Training loss at epoch 906 : 0.269172, Training Acc : 0.871094
# Training loss at epoch 907 : 0.265273, Training Acc : 0.884766
# Training loss at epoch 908 : 0.269627, Training Acc : 0.873047
# Training loss at epoch 909 : 0.265335, Training Acc : 0.869141
# Training loss at epoch 910 : 0.263889, Training Acc : 0.880859
# Training loss at epoch 911 : 0.266754, Training Acc : 0.876953
# Training loss at epoch 912 : 0.266323, Training Acc : 0.877930
# Training loss at epoch 913 : 0.264397, Training Acc : 0.876953
# Training loss at epoch 914 : 0.265264, Training Acc : 0.877930
# Training loss at epoch 915 : 0.268402, Training Acc : 0.868164
# Training loss at epoch 916 : 0.269270, Training Acc : 0.879883
# Training loss at epoch 917 : 0.266263, Training Acc : 0.866211
# Training loss at epoch 918 : 0.266252, Training Acc : 0.883789
# Training loss at epoch 919 : 0.265471, Training Acc : 0.875000
# Training loss at epoch 920 : 0.267210, Training Acc : 0.881836
# Training loss at epoch 921 : 0.266357, Training Acc : 0.875000
# Training loss at epoch 922 : 0.266283, Training Acc : 0.878906
# Training loss at epoch 923 : 0.266651, Training Acc : 0.872070
# Training loss at epoch 924 : 0.266326, Training Acc : 0.884766
# Training loss at epoch 925 : 0.268772, Training Acc : 0.869141
# Training loss at epoch 926 : 0.266287, Training Acc : 0.876953
# Training loss at epoch 927 : 0.264978, Training Acc : 0.882812
# Training loss at epoch 928 : 0.271397, Training Acc : 0.866211
# Training loss at epoch 929 : 0.266059, Training Acc : 0.875000
# Training loss at epoch 930 : 0.269231, Training Acc : 0.880859
# Training loss at epoch 931 : 0.266767, Training Acc : 0.861328
# Training loss at epoch 932 : 0.267835, Training Acc : 0.883789
# Training loss at epoch 933 : 0.266284, Training Acc : 0.870117
# Training loss at epoch 934 : 0.265083, Training Acc : 0.872070
# Training loss at epoch 935 : 0.265839, Training Acc : 0.878906
# Training loss at epoch 936 : 0.268749, Training Acc : 0.885742
# Training loss at epoch 937 : 0.266206, Training Acc : 0.868164
# Training loss at epoch 938 : 0.265213, Training Acc : 0.871094
# Training loss at epoch 939 : 0.267184, Training Acc : 0.874023
# Training loss at epoch 940 : 0.266980, Training Acc : 0.881836
# Training loss at epoch 941 : 0.266198, Training Acc : 0.882812
# Training loss at epoch 942 : 0.266910, Training Acc : 0.885742
# Training loss at epoch 943 : 0.266564, Training Acc : 0.878906
# Training loss at epoch 944 : 0.267380, Training Acc : 0.878906
# Training loss at epoch 945 : 0.266458, Training Acc : 0.884766
# Training loss at epoch 946 : 0.269352, Training Acc : 0.852539
# Training loss at epoch 947 : 0.262661, Training Acc : 0.885742
# Training loss at epoch 948 : 0.267689, Training Acc : 0.887695
# Training loss at epoch 949 : 0.265979, Training Acc : 0.879883
# Training loss at epoch 950 : 0.266003, Training Acc : 0.887695
# Training loss at epoch 951 : 0.267217, Training Acc : 0.878906
# Training loss at epoch 952 : 0.267234, Training Acc : 0.881836
# Training loss at epoch 953 : 0.266893, Training Acc : 0.879883
# Training loss at epoch 954 : 0.264399, Training Acc : 0.872070
# Training loss at epoch 955 : 0.266252, Training Acc : 0.871094
# Training loss at epoch 956 : 0.269346, Training Acc : 0.871094
# Training loss at epoch 957 : 0.263886, Training Acc : 0.888672
# Training loss at epoch 958 : 0.268779, Training Acc : 0.885742
# Training loss at epoch 959 : 0.267563, Training Acc : 0.886719
# Training loss at epoch 960 : 0.264609, Training Acc : 0.878906
# Training loss at epoch 961 : 0.265245, Training Acc : 0.880859
# Training loss at epoch 962 : 0.267481, Training Acc : 0.877930
# Training loss at epoch 963 : 0.264993, Training Acc : 0.890625
# Training loss at epoch 964 : 0.267869, Training Acc : 0.887695
# Training loss at epoch 965 : 0.264514, Training Acc : 0.884766
# Training loss at epoch 966 : 0.266829, Training Acc : 0.882812
# Training loss at epoch 967 : 0.266287, Training Acc : 0.878906
# Training loss at epoch 968 : 0.264732, Training Acc : 0.888672
# Training loss at epoch 969 : 0.267105, Training Acc : 0.875977
# Training loss at epoch 970 : 0.265589, Training Acc : 0.874023
# Training loss at epoch 971 : 0.267605, Training Acc : 0.875977
# Training loss at epoch 972 : 0.265154, Training Acc : 0.863281
# Training loss at epoch 973 : 0.264866, Training Acc : 0.875977
# Training loss at epoch 974 : 0.266846, Training Acc : 0.882812
# Training loss at epoch 975 : 0.267276, Training Acc : 0.886719
# Training loss at epoch 976 : 0.267317, Training Acc : 0.877930
# Training loss at epoch 977 : 0.267449, Training Acc : 0.873047
# Training loss at epoch 978 : 0.266113, Training Acc : 0.867188
# Training loss at epoch 979 : 0.264854, Training Acc : 0.872070
# Training loss at epoch 980 : 0.262995, Training Acc : 0.886719
# Training loss at epoch 981 : 0.269491, Training Acc : 0.875977
# Training loss at epoch 982 : 0.268574, Training Acc : 0.884766
# Training loss at epoch 983 : 0.266081, Training Acc : 0.876953
# Training loss at epoch 984 : 0.264585, Training Acc : 0.887695
# Training loss at epoch 985 : 0.265241, Training Acc : 0.874023
# Training loss at epoch 986 : 0.263882, Training Acc : 0.878906
# Training loss at epoch 987 : 0.264545, Training Acc : 0.882812
# Training loss at epoch 988 : 0.262758, Training Acc : 0.887695
# Training loss at epoch 989 : 0.266421, Training Acc : 0.863281
# Training loss at epoch 990 : 0.263781, Training Acc : 0.876953
# Training loss at epoch 991 : 0.266446, Training Acc : 0.887695
# Training loss at epoch 992 : 0.261955, Training Acc : 0.884766
# Training loss at epoch 993 : 0.265362, Training Acc : 0.862305
# Training loss at epoch 994 : 0.264825, Training Acc : 0.884766
# Training loss at epoch 995 : 0.265534, Training Acc : 0.887695
# Training loss at epoch 996 : 0.266070, Training Acc : 0.877930
# Training loss at epoch 997 : 0.266980, Training Acc : 0.878906
# Training loss at epoch 998 : 0.264844, Training Acc : 0.881836
# Training loss at epoch 999 : 0.266827, Training Acc : 0.877930
# Training loss at epoch 1000 : 0.263508, Training Acc : 0.886719

# %% [markdown]
# ### Evaluate

# %%
data_iterator = iter(train_dataloader)
nb_batches = len(train_dataloader)
model.eval()
acc = 0 
for x, y, _ in train_dataloader:
    x = x.to(device)
    y = y.long().to(device)
    _, hat_y = model(x)
    acc += (hat_y[:, -1].argmax(1) == y[:, -1]).cpu().numpy().mean()

print(f"Train accuracy: {acc / nb_batches}")
# Out:
# Train accuracy: 0.876953125

# %%
class create_testdataset_for_pytorch(Dataset):
    def __init__(self, N, T, train_dataset, lookback=25):
        X_test = np.empty((0, 2))
        Y_test = np.empty((0,))

        for t in range(T+1, 2*T+1):
            x, y = online_sample_from_task_sequence(t, N)
            if y < 0: y = 0

            X_test = np.concatenate((X_test, x.reshape(1, 2)), axis=0)
            Y_test = np.append(Y_test, y)

        X_train, Y_train = train_dataset.get_data_stream()
        X_test = np.concatenate((X_train, X_test))
        Y_test = np.concatenate((Y_train, Y_test)) 

        X, Y, Xshifted = create_dataset(X_test[T-lookback-1:], Y_test[T-lookback-1:], look_back=lookback)
        X = torch.Tensor(X)
        Y = torch.Tensor(Y)
        Xshifted = torch.Tensor(Xshifted)
        self.X = X
        self.Y = Y
        self.Xshifted = Xshifted
        self.X_train = X_train
        self.Y_train = Y_train

    def get_data_stream(self):
        return self.X_train, self.Y_train

    def __len__(self):
        return len(self.Y)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx], self.Xshifted[idx]

def evaluate(model, testloader, device):
    model.to(device)
    model.eval()
    Y_pred = []
    with torch.no_grad():
        for X, _, _ in testloader:
            X = X.to(device)
            _, Y = model(X)
            Y = Y[:, -1].argmax(1).cpu().detach().numpy().tolist()
            Y_pred.extend(Y)
    return Y_pred

# %%
num_reps = 100
model.eval()
predictions = np.zeros((num_reps, T-1))
groundtruth = np.zeros((num_reps, T-1))
accuracy_list = []
for rep in range(num_reps):
    test_dataset = create_testdataset_for_pytorch(N, T, train_dataset, lookback)
    testloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    Y_pred = evaluate(model, testloader, device)
    Y_t = test_dataset.Y.int().numpy()
    predictions[rep, :] = Y_pred
    groundtruth[rep, :] = Y_t[:, -1]

    accuracy_list.append(np.mean(np.array(Y_pred) == Y_t[:, -1]))
mean_error = np.mean(predictions != groundtruth, axis=0)
std_error = np.std(predictions != groundtruth, axis=0)
ci = std_error * 1.96/np.sqrt(num_reps)

# %%
print("Average test accuracy : {:4f} +/- {:4f}".format(np.mean(accuracy_list), np.std(accuracy_list)))
# Out:
# Average test accuracy : 0.876326 +/- 0.012309

# %%
# compute Bayes error of tasks A and B
n = 10000

# task A
w = np.array([[1, 1]]).T
temp = []
for i in range(100):
    X, Y = batch_sample_from_task_sequence(n, N//2, N)
    Y_hat = np.sign(X @ w).squeeze()
    temp.append(np.mean(Y != Y_hat))
bayes_error_A = np.mean(temp)

# task B
w = np.array([[-1, -1]]).T
temp = []
for i in range(100):
    X, Y = batch_sample_from_task_sequence(n, 3*N//2, N)
    Y_hat = np.sign(X @ w).squeeze()
    temp.append(np.mean(Y != Y_hat))
bayes_error_B = np.mean(temp)

print("Task A Bayes Error : ", bayes_error_A)
print("Task B Bayes Error : ", bayes_error_B)
# Out:
# Task A Bayes Error :  0.078714
# Task B Bayes Error :  1.1000000000000001e-05

# %%
fig, axes = plt.subplots(2, 1, figsize=(20, 8))
ax = axes[0]
end = 200+1
xlocs = np.arange(0, end, N)
for i, x in enumerate(xlocs):
    if i % 2 == 0:
        ax.add_artist(Rectangle((x, 0), N, 2, fc='orange', alpha=0.6))
    else:
        ax.add_artist(Rectangle((x, 0), N, 2, fc='b', alpha=0.6))
ax.set_ylim([-1, 5])
ax.set_xlim([xlocs[0], xlocs[-1]])
ax.legend(["task A", "task B"], loc=1, frameon=False, fontsize=16)
ax.axis('off')

sns.set_style("white")
sns.set_style("ticks")

ax = axes[1]
ax.plot(np.arange(1, end), mean_error[:end-1], c='k')

# plot bayes error
bayes_error = np.zeros(len(np.arange(1, end)))
for t in range(len(bayes_error)):
    if (t // N) % 2 == 0:
        bayes_error[t] = bayes_error_A
    else:
        bayes_error[t] = bayes_error_B

ax.plot(np.arange(1, end), bayes_error, c='r', ls='--')
x = np.arange(1, end)
y = mean_error[:end-1]
c = ci[:end-1]
plt.fill_between(x, y-c, y+c, alpha=0.2, color='k')
ax.set_ylabel("Transformer" + "\n" + "Error", fontsize=16)
ax.spines[['right', 'top']].set_visible(False)
ax.tick_params(labelsize=13)
ax.set_xlim([xlocs[0], xlocs[-1]])
ax.set_ylim([0, 1])
ax.legend(['Error', 'Bayes Error'])
plt.show()

# %% [markdown]
# ### Comparison with online learners

# %%
ogd_error = np.load('results/ogd_error.npy')
ftl_error = np.load('results/ftl_error.npy')
c_ogd = np.load('results/ogd_conf.npy')
c_ftl = np.load('results/ftl_conf.npy')

# %%
left = [['left1'], 
        ['left2'],]
right = [['right1'],
         ['right2']]
fig, axes = plt.subplot_mosaic([[left, right]], figsize=(20, 8))

ax = axes['left1']

sns.set_palette('pastel')

x, y = np.mgrid[-3:3:.1, -3:3:.1]
rv = multivariate_normal([0.8, 0.8], 0.20*np.eye(2))
data = np.dstack((x, y))
z1 = rv.pdf(data)
rv = multivariate_normal([-0.8, -0.8], 0.20*np.eye(2))
data = np.dstack((x, y))
z2 = rv.pdf(data)
z = z1 - z2
ax.contourf(x, y, z, cmap='bwr', levels=100, alpha=1, extend='both')

ax.plot([-1, 1], [-1, 1], c='k', lw=3, ls="dashed")
ax.scatter([0], [0], c='k', s=40)
ax.scatter([1], [1], c='k', s=40)
ax.scatter([-1], [-1], c='k', s=40)
ax.text(-0.4, 0, "O", size='small')
ax.text(-1.2, -1.2, r"$-\mu$", size='large', ha='right', color='white')
ax.text(1.2, 1.2, r"$\mu$", size='large', ha='left', color='white')
ax.set_xlim([-2.5, 2.5])
ax.set_ylim([-2.5, 2.5])
ax.set_aspect("equal")
ax.set_title("Task A", fontsize=16)
ax.spines[['right', 'top', 'bottom', 'left']].set_visible(False)
# ax.legend(["Y = 1", "Y = -1"], fontsize=13, frameon=False, loc=2)
ax.set_xticks([])
ax.set_yticks([])

ax = axes['left2']

x, y = np.mgrid[-3:3:.1, -3:3:.1]
rv = multivariate_normal([-1.2, -1.2], 0.20*np.eye(2))
data = np.dstack((x, y))
z1 = rv.pdf(data)
rv = multivariate_normal([1.2, 1.2], 0.20*np.eye(2))
data = np.dstack((x, y))
z2 = rv.pdf(data)
z = z1 - z2
ax.contourf(x, y, z, cmap='bwr', levels=100, alpha=1, extend='both')

ax.plot([-1, 1], [-1, 1], c='k', lw=3, ls="dashed")
ax.scatter([0], [0], c='k', s=40)
ax.scatter([1], [1], c='k', s=40)
ax.scatter([-1], [-1], c='k', s=40)
ax.text(-0.4, 0, "O", size='small')
ax.text(-1.2, -1.2, r"$-3\mu$", size='large', ha='right', color='white')
ax.text(1.2, 1.2, r"$3\mu$", size='large', ha='left', color='white')
ax.set_xlim([-2.5, 2.5])
ax.set_ylim([-2.5, 2.5])
ax.set_aspect("equal")
ax.set_title("Task B", fontsize=16)
ax.spines[['right', 'top', 'bottom', 'left']].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

ax = axes['right1']
xlocs = np.arange(0, end-1, N)
for i, x in enumerate(xlocs):
    if i % 2 == 0:
        ax.add_artist(Rectangle((x, 0), N, 1, fc='purple', alpha=0.6))
    else:
        ax.add_artist(Rectangle((x, 0), N, 1, fc='g', alpha=0.6))
ax.set_ylim([-1, 5])
ax.legend(["task A", "task B"], loc=1, frameon=False, fontsize=16)
ax.axis('off')

sns.set_style("white")
sns.set_style("ticks")
sns.set_palette('pastel')

ax = axes['right2']
ax.plot(np.arange(1, end-1), ogd_error[:end-1], c='#2c7bb6')
x = np.arange(1, end-1)
y = ogd_error[:end-1]
c = c_ogd[:end-1]
ax.fill_between(x, y-c, y+c, alpha=0.2, color='#2c7bb6')

ax.plot(np.arange(1, end-1), ftl_error[:end-1], c='#fdae61')
x = np.arange(1, end-1)
y = ftl_error[:end-1]
c = c_ftl[:end-1]
ax.fill_between(x, y-c, y+c, alpha=0.2, color='#fdae61')

ax.plot(np.arange(1, end), mean_error[:end-1], c='#d7191c')
x = np.arange(1, end)
y = mean_error[:end-1]
c = ci[:end-1]
ax.fill_between(x, y-c, y+c, alpha=0.2, color='#d7191c')

ax.set_ylabel("Error", fontsize=16)
ax.spines[['right', 'top']].set_visible(False)
ax.tick_params(labelsize=13)

legend_elements = [Line2D([0], [0], color='#2c7bb6', lw=4, label='Online Grad. Descent'),
                    Line2D([0], [0], color='#fdae61', lw=4, label='Follow-the-Leader'),
                    Line2D([0], [0], color='#d7191c', lw=4, label='Autoreg-Transformer'),
                ]

ax.legend(handles=legend_elements, loc=8, bbox_to_anchor=(0.2, -0.3, 0.5, 0.5), ncol=3, frameon=False)

axes['right1'].set_xlim(ax.get_xlim())
plt.subplots_adjust(wspace=-0.2)
plt.show()

# %%
fig.savefig("figures/transformer-results.pdf", bbox_inches='tight')
